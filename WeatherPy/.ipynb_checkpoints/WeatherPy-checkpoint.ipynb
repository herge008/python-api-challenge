# %% [markdown]
# ***
# <font size="10"><b>WeatherPy<b></font>
# ***

# %% [markdown]
# # SETUP

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import os

from api_keys import weather_api_key
from api_keys import gkey

from citipy import citipy

# Output file
output_data_file = "output_data/cities.csv"
output_data_path = os.path.join("..", "output_data")

# Range of latitudes & Longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # GENERATE CITIES LIST

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %% [markdown]
# # GET DATA

# %% [markdown]
# #### Perform API Calls

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

citynm = []
cityid = []
country = []
lat = []
lng = []
temp = []
hum = []
cloud = []
wind = []
results = []

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Loop each city from the cities list generated above:
for city in cities:
    response = requests.get(query_url + city).json()    
    try:
        citynm_search = response['name']
        cityid_search = response['id']
        citynm.append(response['name'])
        cityid.append(response['id'])
        country.append(response['sys']['country'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response["main"]["temp_max"])
        hum.append(response["main"]["humidity"])
        cloud.append(response["clouds"]["all"])
        wind.append(response["wind"]["speed"])
        results.append(print(f"Search for {citynm_search} (ID: {cityid_search}) found. Results added to library."))
    except (KeyError, IndexError):
        results.append(print(f"***Search for {city} not found. Skipping."))
    time.sleep(1)
        
# Include a print log of each city as it'sbeing processed (with the city number and city name)
# Out:
# Search for Saint Anthony (ID: 5044290) found. Results added to library.
# Search for New Norfolk (ID: 2155415) found. Results added to library.
# Search for Santa Fe (ID: 3836277) found. Results added to library.
# Search for Rio Gallegos (ID: 3838859) found. Results added to library.
# Search for Ust-Kuyga (ID: 2013921) found. Results added to library.
# Search for Thinadhoo (ID: 1337610) found. Results added to library.
# Search for Zacualpan (ID: 3979819) found. Results added to library.
# Search for Huarmey (ID: 3939168) found. Results added to library.
# Search for Ushuaia (ID: 3833367) found. Results added to library.
# Search for Sattenapalle (ID: 1257001) found. Results added to library.
# Search for Hailey (ID: 5594956) found. Results added to library.
# Search for Kiryat Gat (ID: 293842) found. Results added to library.
# Search for Tuktoyaktuk (ID: 6170031) found. Results added to library.
# Search for Vaini (ID: 4032243) found. Results added to library.
# Search for Mataura (ID: 6201424) found. Results added to library.
# Search for Mossamedes (ID: 3347019) found. Results added to library.
# Search for Mahebourg (ID: 934322) found. Results added to library.
# Search for Rikitea (ID: 4030556) found. Results added to library.
# Search for Kruisfontein (ID: 986717) found. Results added to library.
# Search for Poco das Trincheiras (ID: 3391686) found. Results added to library.
# Search for Dingle (ID: 1714733) found. Results added to library.
# Search for Qaqortoq (ID: 3420846) found. Results added to library.
# Search for Kangalassy (ID: 2023190) found. Results added to library.
# Search for Kargasok (ID: 1504382) found. Results added to library.
# Search for Leningradskiy (ID: 2123814) found. Results added to library.
# Search for Provideniya (ID: 4031574) found. Results added to library.
# Search for Bahia Blanca (ID: 3865086) found. Results added to library.
# Search for Albany (ID: 5106841) found. Results added to library.
# Search for Mar del Plata (ID: 3430863) found. Results added to library.
# Search for Cravo Norte (ID: 3685702) found. Results added to library.
# Search for Yellowknife (ID: 6185377) found. Results added to library.
# Search for Avarua (ID: 4035715) found. Results added to library.
# Search for Kyshtovka (ID: 1501000) found. Results added to library.
# Search for Conceicao do Araguaia (ID: 3401845) found. Results added to library.
# Search for Santa Rosalia (ID: 3983805) found. Results added to library.
# Search for Bredasdorp (ID: 1015776) found. Results added to library.
# Search for Bluff (ID: 2206939) found. Results added to library.
# Search for Kalmunai (ID: 1242110) found. Results added to library.
# Search for Ribeira Grande (ID: 3372707) found. Results added to library.
# Search for Xiongzhou (ID: 1788402) found. Results added to library.
# Search for Lebu (ID: 3883457) found. Results added to library.
# Search for Jamestown (ID: 5122534) found. Results added to library.
# Search for Carutapera (ID: 3402648) found. Results added to library.
# Search for Gobabis (ID: 3357247) found. Results added to library.
# Search for Hobart (ID: 2163355) found. Results added to library.
# Search for Nicoya (ID: 3622716) found. Results added to library.
# Search for Salalah (ID: 286621) found. Results added to library.
# Search for Nyurba (ID: 2018735) found. Results added to library.
# Search for La Rioja (ID: 3848950) found. Results added to library.
# Search for Padang (ID: 1633419) found. Results added to library.
# Search for Margate (ID: 2643044) found. Results added to library.
# Search for Makakilo City (ID: 5850554) found. Results added to library.
# Search for Punta Arenas (ID: 3874787) found. Results added to library.
# Search for Sakakah (ID: 102527) found. Results added to library.
# Search for Iqaluit (ID: 5983720) found. Results added to library.
# Search for Bafoulabe (ID: 2460755) found. Results added to library.
# Search for Fairbanks (ID: 5861897) found. Results added to library.
# Search for Bethel (ID: 5282297) found. Results added to library.
# Search for Cape Town (ID: 3369157) found. Results added to library.
# ***Search for barentsburg not found. Skipping.
# Search for Saldanha (ID: 3361934) found. Results added to library.
# Search for Los Llanos de Aridane (ID: 2514651) found. Results added to library.
# Search for Thompson (ID: 6165406) found. Results added to library.
# Search for Talaya (ID: 2120769) found. Results added to library.
# Search for Puerto Ayora (ID: 3652764) found. Results added to library.
# Search for Port Elizabeth (ID: 964420) found. Results added to library.
# Search for Saint-Philippe (ID: 935215) found. Results added to library.
# Search for Malakanagiri (ID: 1264075) found. Results added to library.
# Search for College (ID: 5859699) found. Results added to library.
# Search for Kavaratti (ID: 1267390) found. Results added to library.
# Search for Port Alfred (ID: 964432) found. Results added to library.
# Search for Helong (ID: 2036933) found. Results added to library.
# ***Search for burica not found. Skipping.
# Search for Khasan (ID: 2039557) found. Results added to library.
# Search for Teluk Nibung (ID: 1213493) found. Results added to library.
# ***Search for taolanaro not found. Skipping.
# Search for Bima (ID: 1648759) found. Results added to library.
# Search for Manaure (ID: 3675504) found. Results added to library.
# Search for Barrow (ID: 5880054) found. Results added to library.
# Search for Saravan (ID: 174726) found. Results added to library.
# Search for Bambous Virieux (ID: 1106677) found. Results added to library.
# Search for Yar-Sale (ID: 1486321) found. Results added to library.
# Search for Khatanga (ID: 2022572) found. Results added to library.
# Search for Hilo (ID: 5855927) found. Results added to library.
# Search for Tabas (ID: 113659) found. Results added to library.
# ***Search for illoqqortoormiut not found. Skipping.
# Search for Aksu (ID: 1529660) found. Results added to library.
# Search for Dvinskoy (ID: 563990) found. Results added to library.
# Search for Belmonte (ID: 3470137) found. Results added to library.
# Search for La Suiza (ID: 3623112) found. Results added to library.
# Search for Aklavik (ID: 5882953) found. Results added to library.
# Search for Talnakh (ID: 1490256) found. Results added to library.
# Search for Port Lincoln (ID: 2063036) found. Results added to library.
# Search for Acapulco de Juarez (ID: 3533462) found. Results added to library.
# Search for Melfort (ID: 6071876) found. Results added to library.
# Search for Butaritari (ID: 2110227) found. Results added to library.
# Search for Kapaa (ID: 5848280) found. Results added to library.
# Search for Cherskiy (ID: 2126199) found. Results added to library.
# Search for Souillac (ID: 933995) found. Results added to library.
# Search for Dunmore Town (ID: 3572462) found. Results added to library.
# ***Search for nizhneyansk not found. Skipping.
# ***Search for lolua not found. Skipping.
# Search for Porto Walter (ID: 3662761) found. Results added to library.
# ***Search for grand river south east not found. Skipping.
# Search for Mackenzie (ID: 6063191) found. Results added to library.
# Search for Nabire (ID: 1634614) found. Results added to library.
# Search for Chokurdakh (ID: 2126123) found. Results added to library.
# Search for Bengkulu (ID: 1649150) found. Results added to library.
# Search for Shelburne (ID: 6145890) found. Results added to library.
# Search for Bayeux (ID: 3405940) found. Results added to library.
# Search for Rio Grande (ID: 3451138) found. Results added to library.
# Search for Vestmanna (ID: 2610343) found. Results added to library.
# Search for Arraial do Cabo (ID: 3471451) found. Results added to library.
# ***Search for vaitupu not found. Skipping.
# Search for Vestmannaeyjar (ID: 3412093) found. Results added to library.
# ***Search for umzimvubu not found. Skipping.
# Search for Carnarvon (ID: 2074865) found. Results added to library.
# Search for Port Moresby (ID: 2088122) found. Results added to library.
# Search for Lorengau (ID: 2092164) found. Results added to library.
# Search for Norman Wells (ID: 6089245) found. Results added to library.
# Search for Salaberry-de-Valleyfield (ID: 6139289) found. Results added to library.
# Search for Carroll (ID: 4350461) found. Results added to library.
# Search for Saddiqabad (ID: 1166652) found. Results added to library.
# ***Search for ye not found. Skipping.
# Search for Touros (ID: 3386213) found. Results added to library.
# Search for Tazovsky (ID: 1489853) found. Results added to library.
# Search for Mitsamiouli (ID: 921786) found. Results added to library.
# Search for Yola (ID: 2318044) found. Results added to library.
# Search for Fershampenuaz (ID: 562878) found. Results added to library.
# Search for Azua (ID: 3512208) found. Results added to library.
# Search for Kodiak (ID: 5866583) found. Results added to library.
# Search for Airai (ID: 1651810) found. Results added to library.
# Search for Cabedelo (ID: 3404558) found. Results added to library.
# Search for Longyearbyen (ID: 2729907) found. Results added to library.
# Search for Ayer Molek (ID: 1734759) found. Results added to library.
# Search for Jacksonville (ID: 4160021) found. Results added to library.
# Search for Narasannapeta (ID: 1261853) found. Results added to library.
# Search for Brae (ID: 2654970) found. Results added to library.
# Search for Buarcos (ID: 2741961) found. Results added to library.
# ***Search for halalo not found. Skipping.
# Search for East London (ID: 1006984) found. Results added to library.
# Search for 'Ahuimanu (ID: 5856516) found. Results added to library.
# ***Search for westpunt not found. Skipping.
# Search for Flinders (ID: 6255012) found. Results added to library.
# Search for Oranjemund (ID: 3354071) found. Results added to library.
# Search for Chui (ID: 3443061) found. Results added to library.
# Search for Saurimo (ID: 145531) found. Results added to library.
# Search for Castro (ID: 3466704) found. Results added to library.
# Search for Itanhem (ID: 3460785) found. Results added to library.
# Search for George Town (ID: 1735106) found. Results added to library.
# Search for Eresos (ID: 262629) found. Results added to library.
# ***Search for ouranopolis not found. Skipping.
# Search for Tura (ID: 1254046) found. Results added to library.
# Search for Poum (ID: 2138555) found. Results added to library.
# ***Search for marcona not found. Skipping.
# Search for Husavik (ID: 2629833) found. Results added to library.
# Search for Sao Paulo de Olivenca (ID: 3662252) found. Results added to library.
# Search for Karratha (ID: 6620339) found. Results added to library.
# Search for Atasu (ID: 1526041) found. Results added to library.
# Search for Clyde River (ID: 5924351) found. Results added to library.
# Search for Zhireken (ID: 2012510) found. Results added to library.
# Search for Lata (ID: 2738381) found. Results added to library.
# Search for Busselton (ID: 2075265) found. Results added to library.
# Search for Atuona (ID: 4020109) found. Results added to library.
# Search for Poco Verde (ID: 3453300) found. Results added to library.
# Search for Hermanus (ID: 3366880) found. Results added to library.
# Search for Vila Franca do Campo (ID: 3372472) found. Results added to library.
# Search for Dargaville (ID: 2191911) found. Results added to library.
# Search for Ubari (ID: 2219235) found. Results added to library.
# Search for Isangel (ID: 2136825) found. Results added to library.
# Search for Hamilton (ID: 4513583) found. Results added to library.
# Search for Irbeyskoye (ID: 1505529) found. Results added to library.
# Search for Guerrero Negro (ID: 4021858) found. Results added to library.
# Search for Srivardhan (ID: 1255619) found. Results added to library.
# ***Search for attawapiskat not found. Skipping.
# Search for Deer Lake (ID: 5937252) found. Results added to library.
# Search for Salym (ID: 1493162) found. Results added to library.
# Search for Hithadhoo (ID: 1282256) found. Results added to library.
# Search for Nishihara (ID: 1855342) found. Results added to library.
# Search for Fortuna (ID: 5563839) found. Results added to library.
# Search for Nikolskoye (ID: 546105) found. Results added to library.
# Search for Baie-Saint-Paul (ID: 6690232) found. Results added to library.
# Search for Beisfjord (ID: 3144987) found. Results added to library.
# Search for Batsfjord (ID: 780717) found. Results added to library.
# Search for Lodwar (ID: 189280) found. Results added to library.
# Search for Tabou (ID: 2281120) found. Results added to library.
# Search for Moose Factory (ID: 6078372) found. Results added to library.
# Search for Zhigansk (ID: 2012530) found. Results added to library.
# Search for Ostrovnoy (ID: 556268) found. Results added to library.
# Search for Tuatapere (ID: 2180815) found. Results added to library.
# Search for Gonder (ID: 336014) found. Results added to library.
# Search for Esperance (ID: 2071860) found. Results added to library.
# Search for Kiunga (ID: 2093846) found. Results added to library.
# Search for Changji (ID: 1529569) found. Results added to library.
# Search for Pochutla (ID: 3517970) found. Results added to library.
# Search for Tromso (ID: 6453316) found. Results added to library.
# Search for Klaksvik (ID: 2618795) found. Results added to library.
# Search for Kaitangata (ID: 2208248) found. Results added to library.
# Search for Kualakapuas (ID: 1639304) found. Results added to library.
# Search for Geraldton (ID: 2070998) found. Results added to library.
# Search for Yong'an (ID: 1806687) found. Results added to library.
# Search for Nuuk (ID: 3421319) found. Results added to library.
# Search for Vardo (ID: 777019) found. Results added to library.
# ***Search for tsihombe not found. Skipping.
# Search for Dikson (ID: 1507390) found. Results added to library.
# ***Search for belushya guba not found. Skipping.
# Search for Honiara (ID: 2108502) found. Results added to library.
# Search for Meru (ID: 186827) found. Results added to library.
# Search for Veraval (ID: 1253237) found. Results added to library.
# Search for Luga (ID: 533690) found. Results added to library.
# Search for La Ronge (ID: 6050066) found. Results added to library.
# Search for Bundaberg (ID: 2173323) found. Results added to library.
# Search for Baltay (ID: 579381) found. Results added to library.
# Search for Akdepe (ID: 601551) found. Results added to library.
# Search for Merauke (ID: 2082539) found. Results added to library.
# Search for Tsilna (ID: 480884) found. Results added to library.
# Search for North Platte (ID: 5697939) found. Results added to library.
# Search for Sitka (ID: 5557293) found. Results added to library.
# Search for Pangoa (ID: 3933104) found. Results added to library.
# Search for San Andres (ID: 3670218) found. Results added to library.
# Search for Akhtanizovskaya (ID: 583811) found. Results added to library.
# Search for Bakchar (ID: 1511057) found. Results added to library.
# Search for Kargil (ID: 1267776) found. Results added to library.
# ***Search for lushunkou not found. Skipping.
# Search for Tiksi (ID: 2015306) found. Results added to library.
# ***Search for ijaki not found. Skipping.
# Search for Altamont (ID: 5711149) found. Results added to library.
# Search for Hasaki (ID: 2112802) found. Results added to library.
# Search for Sittwe (ID: 1295765) found. Results added to library.
# Search for Faya (ID: 110690) found. Results added to library.
# Search for Baykit (ID: 1510689) found. Results added to library.
# ***Search for rungata not found. Skipping.
# Search for Pevek (ID: 2122090) found. Results added to library.
# Search for Sinnamary (ID: 3380290) found. Results added to library.
# Search for Kuala Terengganu (ID: 1734705) found. Results added to library.
# Search for Tiznit (ID: 2527087) found. Results added to library.
# Search for Dongsheng (ID: 1812256) found. Results added to library.
# Search for Lagoa (ID: 3372964) found. Results added to library.
# Search for Sangar (ID: 2017215) found. Results added to library.
# Search for Colomi (ID: 3919813) found. Results added to library.
# Search for AEaenekoski (ID: 662095) found. Results added to library.
# Search for Sabang (ID: 1214026) found. Results added to library.
# ***Search for amderma not found. Skipping.
# Search for Magalia (ID: 5369690) found. Results added to library.
# Search for San Vicente (ID: 3428068) found. Results added to library.
# Search for Charters Towers (ID: 2171722) found. Results added to library.
# Search for Torbay (ID: 6167817) found. Results added to library.
# Search for Tautira (ID: 4033557) found. Results added to library.
# Search for Gamba (ID: 2400547) found. Results added to library.
# Search for Simao (ID: 1794209) found. Results added to library.
# Search for Qaanaaq (ID: 3831208) found. Results added to library.
# Search for Saint George (ID: 5546220) found. Results added to library.
# Search for Tasiilaq (ID: 3424607) found. Results added to library.
# Search for Ciurila (ID: 681371) found. Results added to library.
# Search for Dunedin (ID: 2191562) found. Results added to library.
# Search for Abu Dhabi (ID: 292968) found. Results added to library.
# Search for Ucluelet (ID: 6171633) found. Results added to library.
# Search for Koulikoro (ID: 2454532) found. Results added to library.
# Search for San Patricio (ID: 3985168) found. Results added to library.
# Search for Egvekinot (ID: 4031742) found. Results added to library.
# Search for Muros (ID: 3115824) found. Results added to library.
# Search for Upernavik (ID: 3418910) found. Results added to library.
# Search for Erenhot (ID: 2037485) found. Results added to library.
# Search for Nagato (ID: 1899102) found. Results added to library.
# Search for Aswan (ID: 359792) found. Results added to library.
# Search for Adrar (ID: 2381972) found. Results added to library.
# Search for Waipawa (ID: 2206874) found. Results added to library.
# Search for Ryotsu (ID: 1853371) found. Results added to library.
# Search for Craig (ID: 5576064) found. Results added to library.
# Search for Saint-Michel-des-Saints (ID: 6138802) found. Results added to library.
# Search for Ancud (ID: 3899695) found. Results added to library.
# Search for Kawalu (ID: 1640902) found. Results added to library.
# Search for Haines Junction (ID: 5969025) found. Results added to library.
# Search for Rizhao (ID: 1797132) found. Results added to library.
# Search for Cidreira (ID: 3466165) found. Results added to library.
# Search for Ajdabiya (ID: 89113) found. Results added to library.
# Search for Manche (ID: 2996268) found. Results added to library.
# ***Search for warqla not found. Skipping.
# Search for Hong Kong (ID: 1819729) found. Results added to library.
# Search for Kanniyakumari (ID: 1268008) found. Results added to library.
# Search for Urumqi (ID: 1529102) found. Results added to library.
# Search for Hlobyne (ID: 708753) found. Results added to library.
# Search for Sosnovo-Ozerskoye (ID: 2016216) found. Results added to library.
# Search for Yarada (ID: 1252783) found. Results added to library.
# Search for Tual (ID: 1623197) found. Results added to library.
# Search for Kupang (ID: 2057087) found. Results added to library.
# Search for Calvinia (ID: 3369174) found. Results added to library.
# Search for Mayo (ID: 4362001) found. Results added to library.
# Search for Kolkwitz (ID: 2886382) found. Results added to library.
# Search for Rancho Palos Verdes (ID: 5386035) found. Results added to library.
# Search for Saskylakh (ID: 2017155) found. Results added to library.
# ***Search for temaraia not found. Skipping.
# Search for Cabo San Lucas (ID: 3985710) found. Results added to library.
# Search for Nanortalik (ID: 3421765) found. Results added to library.
# Search for Ponta do Sol (ID: 2264557) found. Results added to library.
# Search for Khovd (ID: 1516048) found. Results added to library.
# Search for Arvika (ID: 2725123) found. Results added to library.
# Search for Severo-Kuril'sk (ID: 2121385) found. Results added to library.
# Search for Shanhecun (ID: 2034995) found. Results added to library.
# Search for Saint George's (ID: 3579925) found. Results added to library.
# Search for Pirovskoye (ID: 1494941) found. Results added to library.
# Search for Atamanovka (ID: 2027373) found. Results added to library.
# Search for San Joaquin (ID: 3628267) found. Results added to library.
# Search for Balikpapan (ID: 1650527) found. Results added to library.
# Search for Dickinson (ID: 4686163) found. Results added to library.
# Search for Pecos (ID: 5528182) found. Results added to library.
# Search for Tocopilla (ID: 3869716) found. Results added to library.
# Search for Kenai (ID: 5866063) found. Results added to library.
# Search for Mount Gambier (ID: 2156643) found. Results added to library.
# Search for Mahon (ID: 2514301) found. Results added to library.
# Search for Saint-Francois (ID: 2980080) found. Results added to library.
# Search for Yangi Marg`ilon (ID: 1513491) found. Results added to library.
# Search for Ulladulla (ID: 2145554) found. Results added to library.
# ***Search for uwayl not found. Skipping.
# Search for Mayya (ID: 2020121) found. Results added to library.
# ***Search for skalistyy not found. Skipping.
# Search for Port Hardy (ID: 6111862) found. Results added to library.
# Search for Matara (ID: 1235846) found. Results added to library.
# Search for Pemba (ID: 1028918) found. Results added to library.
# Search for Boyolangu (ID: 1648082) found. Results added to library.
# Search for Payson (ID: 5779548) found. Results added to library.
# ***Search for cockburn harbour not found. Skipping.
# Search for Ketchikan (ID: 5554428) found. Results added to library.
# Search for Buraidah (ID: 107304) found. Results added to library.
# Search for Tutoia (ID: 3385899) found. Results added to library.
# Search for Resistencia (ID: 3429577) found. Results added to library.
# Search for Bilibino (ID: 2126682) found. Results added to library.
# Search for Yangzhou (ID: 1787227) found. Results added to library.
# Search for Inhambane (ID: 1045114) found. Results added to library.
# Search for Verkhoyansk (ID: 2013465) found. Results added to library.
# Search for Codrington (ID: 2171099) found. Results added to library.
# Search for Date (ID: 2130421) found. Results added to library.
# Search for Marawi (ID: 1701054) found. Results added to library.
# Search for Windhoek (ID: 3352136) found. Results added to library.
# ***Search for samusu not found. Skipping.
# Search for Liverpool (ID: 2644210) found. Results added to library.
# Search for Sioux Lookout (ID: 6148373) found. Results added to library.
# Search for Obo (ID: 236950) found. Results added to library.
# Search for Shubarkuduk (ID: 608271) found. Results added to library.
# Search for Ayna (ID: 3946962) found. Results added to library.
# Search for Nemuro (ID: 2128975) found. Results added to library.
# Search for Soyo (ID: 2236967) found. Results added to library.
# Search for Nome (ID: 5870133) found. Results added to library.
# Search for Bereket (ID: 161974) found. Results added to library.
# Search for Cam Ranh (ID: 1586350) found. Results added to library.
# Search for Kudahuvadhoo (ID: 1337607) found. Results added to library.
# Search for Port Blair (ID: 1259385) found. Results added to library.
# Search for Shimoda (ID: 1852357) found. Results added to library.
# Search for Acarau (ID: 3408368) found. Results added to library.
# Search for Pacific Grove (ID: 5380437) found. Results added to library.
# Search for Hay River (ID: 5972762) found. Results added to library.
# Search for San Felipe (ID: 3628423) found. Results added to library.
# Search for Kadaya (ID: 2023324) found. Results added to library.
# Search for Hualmay (ID: 3939761) found. Results added to library.
# Search for Motala (ID: 2690960) found. Results added to library.
# Search for Curuca (ID: 3401188) found. Results added to library.
# ***Search for yuzhno-yeniseyskiy not found. Skipping.
# Search for Clarence Town (ID: 2171465) found. Results added to library.
# Search for Clinton (ID: 4989133) found. Results added to library.
# ***Search for louisbourg not found. Skipping.
# Search for Portland (ID: 5746545) found. Results added to library.
# Search for Lodja (ID: 211647) found. Results added to library.
# Search for Dossor (ID: 610023) found. Results added to library.
# Search for Noumea (ID: 2139521) found. Results added to library.
# Search for Nueva Loja (ID: 3655185) found. Results added to library.
# Search for Mandera (ID: 187896) found. Results added to library.
# Search for Half Moon Bay (ID: 5354943) found. Results added to library.
# Search for Kandrian (ID: 2094746) found. Results added to library.
# Search for Paamiut (ID: 3421193) found. Results added to library.
# Search for Samarai (ID: 2132606) found. Results added to library.
# Search for Caravelas (ID: 3466980) found. Results added to library.
# Search for Edd (ID: 338345) found. Results added to library.
# Search for Saint-Joseph (ID: 6690296) found. Results added to library.
# Search for Goundam (ID: 2456917) found. Results added to library.
# ***Search for guekedou not found. Skipping.
# Search for Eldorado (ID: 3464343) found. Results added to library.
# Search for Nador (ID: 2541479) found. Results added to library.
# Search for Verkhnevilyuysk (ID: 2013639) found. Results added to library.
# Search for Zhanaozen (ID: 607610) found. Results added to library.
# Search for Lompoc (ID: 5367788) found. Results added to library.
# Search for Ola (ID: 2122574) found. Results added to library.
# Search for Grand-Santi (ID: 3381538) found. Results added to library.
# ***Search for kemijarvi not found. Skipping.
# Search for Kavieng (ID: 2094342) found. Results added to library.
# Search for Cervo (ID: 3125287) found. Results added to library.
# Search for Laguna (ID: 5364271) found. Results added to library.
# Search for Taoudenni (ID: 2450173) found. Results added to library.
# Search for Srednekolymsk (ID: 2121025) found. Results added to library.
# Search for Hammerfest (ID: 779683) found. Results added to library.
# Search for Vostok (ID: 2013279) found. Results added to library.
# Search for Orizona (ID: 3455786) found. Results added to library.
# Search for Leshukonskoye (ID: 535839) found. Results added to library.
# Search for Knysna (ID: 988698) found. Results added to library.
# Search for Baneh (ID: 141584) found. Results added to library.
# Search for Avanuorri (ID: 779622) found. Results added to library.
# Search for Udachny (ID: 2014624) found. Results added to library.
# Search for Senno (ID: 497024) found. Results added to library.
# Search for Dawlatabad (ID: 1142226) found. Results added to library.
# Search for Lakes Entrance (ID: 2160735) found. Results added to library.
# Search for Catalao (ID: 3466696) found. Results added to library.
# Search for Carrollton (ID: 4679195) found. Results added to library.
# Search for Povenets (ID: 505820) found. Results added to library.
# Search for Rock Hill (ID: 4593142) found. Results added to library.
# Search for Yulara (ID: 6355222) found. Results added to library.
# Search for West Fargo (ID: 5062458) found. Results added to library.
# Search for Pindwara (ID: 1259638) found. Results added to library.
# Search for Doong (ID: 1714404) found. Results added to library.
# Search for Aykhal (ID: 2027296) found. Results added to library.
# Search for Ibra (ID: 287832) found. Results added to library.
# Search for Byron Bay (ID: 2172880) found. Results added to library.
# Search for Ballina (ID: 2177069) found. Results added to library.
# Search for Mackay (ID: 2159220) found. Results added to library.
# Search for Coyhaique (ID: 3894426) found. Results added to library.
# ***Search for kamenskoye not found. Skipping.
# Search for Korla (ID: 1529376) found. Results added to library.
# ***Search for tumannyy not found. Skipping.
# Search for Launceston (ID: 2160517) found. Results added to library.
# Search for Dalnerechensk (ID: 2025159) found. Results added to library.
# Search for Bathsheba (ID: 3374083) found. Results added to library.
# Search for Johnson City (ID: 4633419) found. Results added to library.
# ***Search for saleaula not found. Skipping.
# Search for Bandarbeyla (ID: 64814) found. Results added to library.
# ***Search for karauzyak not found. Skipping.
# Search for Opuwo (ID: 3354077) found. Results added to library.
# Search for Puerto del Rosario (ID: 2512186) found. Results added to library.
# Search for Nouakchott (ID: 2377450) found. Results added to library.
# ***Search for bolungarvik not found. Skipping.
# Search for Kuressaare (ID: 590939) found. Results added to library.
# Search for Sterling (ID: 4787534) found. Results added to library.
# Search for Tabatinga (ID: 3662075) found. Results added to library.
# Search for Narsaq (ID: 3421719) found. Results added to library.
# Search for Krasnoarmeysk (ID: 542464) found. Results added to library.
# Search for Carambei (ID: 3467042) found. Results added to library.
# Search for Petropavlovsk-Kamchatsky (ID: 2122104) found. Results added to library.
# ***Search for sentyabrskiy not found. Skipping.
# ***Search for lar gerd not found. Skipping.
# Search for Zambezi (ID: 895953) found. Results added to library.
# Search for Wilmington (ID: 4499379) found. Results added to library.
# Search for Itarema (ID: 3393692) found. Results added to library.
# Search for Demmin (ID: 2938284) found. Results added to library.
# Search for Luanda (ID: 2240449) found. Results added to library.
# Search for Coquimbo (ID: 3893629) found. Results added to library.
# Search for Puerto Escondido (ID: 3520994) found. Results added to library.
# Search for Alice Springs (ID: 2077895) found. Results added to library.
# Search for Arkhipo-Osipovka (ID: 580969) found. Results added to library.
# Search for Nouadhibou (ID: 2377457) found. Results added to library.
# Search for Mehamn (ID: 778707) found. Results added to library.
# Search for Roebourne (ID: 2062276) found. Results added to library.
# Search for Aktobe (ID: 610611) found. Results added to library.
# Search for Kiruna (ID: 605155) found. Results added to library.
# Search for Agogo (ID: 2305537) found. Results added to library.
# Search for Ustka (ID: 3082756) found. Results added to library.
# Search for Luderitz (ID: 3355672) found. Results added to library.
# Search for Skegness (ID: 2637762) found. Results added to library.
# Search for Penarroya-Pueblonuevo (ID: 2512730) found. Results added to library.
# Search for Arman (ID: 2127060) found. Results added to library.
# Search for Singaraja (ID: 1626932) found. Results added to library.
# Search for Wanaka (ID: 2184707) found. Results added to library.
# Search for Chiang Khong (ID: 1611197) found. Results added to library.
# Search for Avera (ID: 4231997) found. Results added to library.
# ***Search for tabulbah not found. Skipping.
# Search for Kaeo (ID: 2189343) found. Results added to library.
# Search for Quang Ngai (ID: 1568770) found. Results added to library.
# Search for Druzhba (ID: 709584) found. Results added to library.
# Search for Taitung City (ID: 6949678) found. Results added to library.
# Search for Rosario (ID: 3838583) found. Results added to library.
# Search for Sturgeon Falls (ID: 5952554) found. Results added to library.
# Search for Harper (ID: 2276492) found. Results added to library.
# Search for Iquique (ID: 3887127) found. Results added to library.
# Search for Havre-Saint-Pierre (ID: 5972291) found. Results added to library.
# Search for Namatanai (ID: 2090021) found. Results added to library.
# Search for Ust'-Kulom (ID: 478050) found. Results added to library.
# Search for Guadalajara (ID: 4005539) found. Results added to library.
# Search for Estepona (ID: 2517816) found. Results added to library.
# Search for Saint-Marc-des-Carrieres (ID: 6138719) found. Results added to library.
# Search for Manakara (ID: 1061605) found. Results added to library.
# ***Search for mys shmidta not found. Skipping.
# Search for Kamina (ID: 214614) found. Results added to library.
# Search for Dryden (ID: 5942913) found. Results added to library.
# Search for Meleuz (ID: 527717) found. Results added to library.
# Search for Horsham (ID: 2646557) found. Results added to library.
# Search for Chinhoyi (ID: 893697) found. Results added to library.
# Search for Zyryanka (ID: 2119283) found. Results added to library.
# Search for Moree (ID: 2156927) found. Results added to library.
# Search for North Bend (ID: 5742974) found. Results added to library.
# Search for Andenes (ID: 3163146) found. Results added to library.
# Search for Mashhad (ID: 124665) found. Results added to library.
# Search for Brownwood (ID: 4676798) found. Results added to library.
# Search for Leiyang (ID: 1804208) found. Results added to library.
# Search for Azul (ID: 3436199) found. Results added to library.
# Search for Aasiaat (ID: 3424901) found. Results added to library.
# Search for Boa Vista (ID: 3664980) found. Results added to library.
# Search for Vilyuysk (ID: 2013392) found. Results added to library.
# Search for Grande Riviere Noire (ID: 934089) found. Results added to library.
# ***Search for sorvag not found. Skipping.
# Search for Ahipara (ID: 2194098) found. Results added to library.
# Search for Marsaxlokk (ID: 2562247) found. Results added to library.
# ***Search for tabiauea not found. Skipping.
# Search for Kungurtug (ID: 1501377) found. Results added to library.
# Search for Antofagasta (ID: 3899539) found. Results added to library.
# Search for Asuncion (ID: 3439389) found. Results added to library.
# ***Search for haibowan not found. Skipping.
# Search for Biu (ID: 2346995) found. Results added to library.
# Search for Aktau (ID: 610612) found. Results added to library.
# Search for Tigil (ID: 2120612) found. Results added to library.
# Search for Dergachi (ID: 566456) found. Results added to library.
# Search for Okhotsk (ID: 2122605) found. Results added to library.
# Search for Quipile (ID: 3671072) found. Results added to library.
# Search for Lashio (ID: 1314759) found. Results added to library.
# Search for Fort Saint James (ID: 5881688) found. Results added to library.
# Search for Vershino-Shakhtaminskiy (ID: 2013441) found. Results added to library.
# Search for Praia (ID: 3374333) found. Results added to library.
# Search for Praia (ID: 3374333) found. Results added to library.
# Search for Isla Vista (ID: 5359864) found. Results added to library.
# Search for Abu Zabad (ID: 380348) found. Results added to library.
# Search for Hvide Sande (ID: 2619537) found. Results added to library.
# Search for Kroya (ID: 1639337) found. Results added to library.
# Search for Majur (ID: 3195895) found. Results added to library.
# Search for San Quintin (ID: 3984997) found. Results added to library.
# Search for Velim (ID: 3063286) found. Results added to library.
# Search for Niigata (ID: 1855431) found. Results added to library.
# Search for Coruripe (ID: 3465329) found. Results added to library.
# Search for Alugan (ID: 1731248) found. Results added to library.
# Search for Aguada de Pasajeros (ID: 3569546) found. Results added to library.
# Search for Moctezuma (ID: 3995647) found. Results added to library.
# Search for Solnechnyy (ID: 2016307) found. Results added to library.
# Search for Manali (ID: 1263968) found. Results added to library.
# Search for Buin (ID: 3897774) found. Results added to library.
# Search for Grindavik (ID: 3416888) found. Results added to library.
# Search for Sheridan (ID: 5838199) found. Results added to library.
# Search for Bilma (ID: 2446796) found. Results added to library.
# Search for Sept-Iles (ID: 6144312) found. Results added to library.
# Search for Katsuura (ID: 2112309) found. Results added to library.
# Search for Alexandria (ID: 361058) found. Results added to library.
# Search for Chegdomyn (ID: 2025579) found. Results added to library.
# Search for Whitehorse (ID: 6180550) found. Results added to library.
# Search for Brownsville (ID: 4676740) found. Results added to library.
# Search for Vilhena (ID: 3924679) found. Results added to library.
# Search for Atambua (ID: 1651103) found. Results added to library.
# Search for Beringovskiy (ID: 2126710) found. Results added to library.
# Search for Corning (ID: 5113760) found. Results added to library.
# Search for Boralday (ID: 1526384) found. Results added to library.
# Search for Macusani (ID: 3935624) found. Results added to library.
# Search for Ugoofaaru (ID: 1337619) found. Results added to library.
# Search for Pangody (ID: 1495626) found. Results added to library.
# Search for Mahon (ID: 2514301) found. Results added to library.
# Search for Port Macquarie (ID: 2152659) found. Results added to library.
# Search for Moerai (ID: 4034188) found. Results added to library.
# Search for Hanawa (ID: 2130146) found. Results added to library.
# Search for Tete (ID: 1026014) found. Results added to library.
# Search for Severnyy (ID: 496358) found. Results added to library.
# Search for Cooma (ID: 2170577) found. Results added to library.
# Search for Oktyabrskoye (ID: 515805) found. Results added to library.
# ***Search for rawannawi not found. Skipping.
# Search for Maragogi (ID: 3395458) found. Results added to library.
# Search for Goderich (ID: 5962442) found. Results added to library.
# Search for Krasnokamensk (ID: 2021618) found. Results added to library.
# Search for Puerto Carreno (ID: 3671519) found. Results added to library.
# Search for Mattru (ID: 2409215) found. Results added to library.
# Search for Ritchie (ID: 961226) found. Results added to library.
# Search for Vila Velha (ID: 3445026) found. Results added to library.
# Search for Smithers (ID: 6149996) found. Results added to library.
# Search for Callaguip (ID: 1720223) found. Results added to library.
# Search for Deputatsky (ID: 2028164) found. Results added to library.
# Search for Faanui (ID: 4034551) found. Results added to library.
# Search for Viedma (ID: 3832899) found. Results added to library.
# Search for Riyadh (ID: 108410) found. Results added to library.
# Search for Turka (ID: 690960) found. Results added to library.
# Search for Purificacion (ID: 3671208) found. Results added to library.
# Search for Kuytun (ID: 2021093) found. Results added to library.
# Search for Marabu (ID: 1738050) found. Results added to library.
# Search for Kulhudhuffushi (ID: 1337613) found. Results added to library.
# Search for Gravdal (ID: 3155152) found. Results added to library.
# ***Search for palabuhanratu not found. Skipping.
# Search for Port-Gentil (ID: 2396518) found. Results added to library.
# Search for Constitucion (ID: 3893726) found. Results added to library.
# Search for Lumphat (ID: 1830377) found. Results added to library.
# Search for Louangphabang (ID: 1655559) found. Results added to library.
# Search for Kahului (ID: 5847411) found. Results added to library.
# Search for Beberibe (ID: 3405924) found. Results added to library.
# Search for Savelugu (ID: 2295517) found. Results added to library.
# Search for Birjand (ID: 140463) found. Results added to library.
# Search for Pravokumskoye (ID: 505581) found. Results added to library.
# Search for Nongpoh (ID: 1261208) found. Results added to library.
# Search for Basco (ID: 1726449) found. Results added to library.
# Search for Vao (ID: 2137773) found. Results added to library.
# Search for Malbork (ID: 3092472) found. Results added to library.
# Search for Mangrol (ID: 1263752) found. Results added to library.
# Search for Balkhash (ID: 1525798) found. Results added to library.
# Search for Ilulissat (ID: 3423146) found. Results added to library.
# Search for Santo Andre (ID: 3449701) found. Results added to library.
# Search for Verkhnyaya Inta (ID: 1487332) found. Results added to library.
# Search for Neftcala (ID: 147425) found. Results added to library.
# Search for Taldan (ID: 2015646) found. Results added to library.
# Search for Breves (ID: 3404817) found. Results added to library.
# Search for Cartagena (ID: 3687238) found. Results added to library.
# Search for Along (ID: 1278969) found. Results added to library.
# ***Search for kuche not found. Skipping.
# Search for Wanning (ID: 1791779) found. Results added to library.
# Search for San Jacinto (ID: 5392090) found. Results added to library.
# Search for Kinsale (ID: 2963155) found. Results added to library.
# Search for Auki (ID: 2109701) found. Results added to library.
# ***Search for jabiru not found. Skipping.
# Search for Alofi (ID: 4036284) found. Results added to library.
# Search for Waidhofen (ID: 2815315) found. Results added to library.
# Search for Havelock (ID: 4470244) found. Results added to library.
# Search for Pangnirtung (ID: 6096551) found. Results added to library.
# Search for Bistra (ID: 684680) found. Results added to library.
# Search for Tarauaca (ID: 3661980) found. Results added to library.
# Search for Micheweni (ID: 153955) found. Results added to library.
# Search for Ambon (ID: 1651531) found. Results added to library.
# Search for Fort Nelson (ID: 5955902) found. Results added to library.
# Search for Kaerdla (ID: 591632) found. Results added to library.
# Search for Puerto Princesa (ID: 1692685) found. Results added to library.
# Search for Ponta Delgada (ID: 3372783) found. Results added to library.
# ***Search for saint-fabien not found. Skipping.
# Search for Maniitsoq (ID: 3421982) found. Results added to library.
# Search for Tabuk (ID: 1684803) found. Results added to library.
# Search for Kumul (ID: 1529484) found. Results added to library.
# Search for Chilakalurupet (ID: 1274213) found. Results added to library.
# Search for Lukang (ID: 1679136) found. Results added to library.
# Search for Port-Cartier (ID: 6111696) found. Results added to library.
# Search for Amga (ID: 2027786) found. Results added to library.
# Search for Shablykino (ID: 496159) found. Results added to library.
# Search for Biri (ID: 1724803) found. Results added to library.
# Search for Daru (ID: 2098329) found. Results added to library.
# Search for Ormara (ID: 1168700) found. Results added to library.
# Search for San-Pedro (ID: 2282006) found. Results added to library.
# Search for Cocoa Beach (ID: 4151441) found. Results added to library.
# Search for Palekastro (ID: 256155) found. Results added to library.

# %%
cityid_ct = len(cityid)
lat_ct = len(lat)
lng_ct = len(lng)
temp_ct = len(temp)
hum_ct = len(hum)
cloud_ct = len(cloud)
wind_ct = len(wind)
print(f"Id Count: {cityid_ct}")
print(f"Lat Count: {lat_ct}")
print(f"Lng Count: {lng_ct}")
print(f"Temp Count: {temp_ct}")
print(f"Hum Count: {hum_ct}")
print(f"Cloud Count: {cloud_ct}")
print(f"Wind Count: {wind_ct}")
# Out:
# Id Count: 582
# Lat Count: 582
# Lng Count: 582
# Temp Count: 582
# Hum Count: 582
# Cloud Count: 582
# Wind Count: 582

# %% [markdown]
# #### Convert Raw Data to DataFrame

# %%
# Display the DataFrame
weather_dict = {
    "City": citynm,
    "CityID": cityid,
    "Country": country,
    "Latitude": lat,
    "Longitude": lng,
    "Temperature": temp,
    "Humidity": hum,
    "Cloudiness": cloud,
    "Wind Speed": wind
}
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#             City   CityID Country  Latitude  Longitude  Temperature  Humidity  \
# 0  Saint Anthony  5044290      US     45.02     -93.22        19.40        92
# 1    New Norfolk  2155415      AU    -42.78     147.06        80.60        34
# 2       Santa Fe  3836277      AR    -31.63     -60.70        81.00        60
# 3   Rio Gallegos  3838859      AR    -51.62     -69.22        46.40        61
# 4      Ust-Kuyga  2013921      RU     70.02     135.60       -28.48        72
#
#    Cloudiness  Wind Speed
# 0          90        1.74
# 1          40       11.41
# 2         100        1.99
# 3          87       21.92
# 4          57        9.40

# %%
weather_df.dtypes
# Out:
# City            object
# CityID           int64
# Country         object
# Latitude       float64
# Longitude      float64
# Temperature    float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# dtype: object

# %%
weather_df.isnull().sum()
# Out:
# City           0
# CityID         0
# Country        0
# Latitude       0
# Longitude      0
# Temperature    0
# Humidity       0
# Cloudiness     0
# Wind Speed     0
# dtype: int64

# %%
# Export the city data into a .csv
weather_df.to_csv(output_data_file, mode = "w", index=False)

# %% [markdown]
# # SCATTER PLOTS

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(15,10))
plt.scatter(weather_df["Latitude"], weather_df["Temperature"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.title("City Latitude vs Max Temperature (F)")
plt.xlabel("City Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig('../output_data/LatvsTemp.png')
plt.show()

# %% [markdown]
# * The figure above shows what basic intuition would yield about temperature in relation to one's relative position of the equator.  The further north you travel, the higher likelihood that you're wearing long sleeves.  Beware though, extreme south does not imply the opposite as lacations circa -50 latitude are recording temps below 60F.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(15,10))
plt.scatter(weather_df["Latitude"], weather_df["Humidity"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.title("City Latitude vs Humidity")
plt.xlabel("City Latitude")
plt.ylabel("Humidity")
plt.grid(True)
plt.savefig('../output_data/LatvsHumidity.png')
plt.show()

# %% [markdown]
# * Latitude and humidity aren't linearally appealing.  You're just as likely to be at 100% humidity at both +40 and -40 latitude.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(15,10))
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.title("City Latitude vs Cloudiness %")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness %")
plt.grid(True)
plt.savefig('../output_data/LatvsCloudiness.png')
plt.show()

# %% [markdown]
# * The amount of dispersion in this chart is enough for me to challenge the accuracy of reporting.  We can clearly see lines forming at 0, 20, 40, 75 90 and 100 on the Cloudiness % axis, but the consistency is most prevalent in the northern hemisphere.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(15,10))
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.title("City Latitude vs Wind Speed")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)
plt.savefig('../output_data/LatvsWind.png')
plt.show()

# %% [markdown]
# * Shocking results on this plot.  The overwhelming majority of locations recording a wind speed less than 15 mph?  Come on..

# %% [markdown]
# # LINEAR REGRESSION

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
weather_df_north = weather_df[weather_df.Latitude >= 0]
weather_df_north.head()
# Out:
#             City   CityID Country  Latitude  Longitude  Temperature  Humidity  \
# 0  Saint Anthony  5044290      US     45.02     -93.22        19.40        92
# 4      Ust-Kuyga  2013921      RU     70.02     135.60       -28.48        72
# 5      Thinadhoo  1337610      MV      0.53      72.93        80.71        76
# 6      Zacualpan  3979819      MX     21.25    -105.17        73.40        93
# 9   Sattenapalle  1257001      IN     16.40      80.18        78.80        83
#
#    Cloudiness  Wind Speed
# 0          90        1.74
# 4          57        9.40
# 5          28       15.50
# 6          20        2.08
# 9          40        4.70

# %%
weather_df_north.shape
# Out:
# (406, 9)

# %%
weather_df_south = weather_df[weather_df.Latitude <= 0]
weather_df_south.head()
# Out:
#            City   CityID Country  Latitude  Longitude  Temperature  Humidity  \
# 1   New Norfolk  2155415      AU    -42.78     147.06        80.60        34
# 2      Santa Fe  3836277      AR    -31.63     -60.70        81.00        60
# 3  Rio Gallegos  3838859      AR    -51.62     -69.22        46.40        61
# 7       Huarmey  3939168      PE    -10.07     -78.15        71.96        75
# 8       Ushuaia  3833367      AR    -54.80     -68.30        42.80        81
#
#    Cloudiness  Wind Speed
# 1          40       11.41
# 2         100        1.99
# 3          87       21.92
# 7         100        3.02
# 8          75       28.86

# %%
weather_df_south.shape
# Out:
# (176, 9)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_north["Latitude"], weather_df_north["Temperature"])
regress_values = weather_df_north["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(15,10))
plt.scatter(weather_df_north["Latitude"], weather_df_north["Temperature"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_north["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(0,-20),
             fontsize=15,
             color="firebrick"
            )
plt.title("Northern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.savefig('../output_data/LatvsTemp_regress_north.png')
plt.show()
# Out:
# The correlation coefficient is: -0.885146646551316

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_south["Latitude"], weather_df_south["Temperature"])
regress_values = weather_df_south["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(15,10))
plt.scatter(weather_df_south["Latitude"], weather_df_south["Temperature"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_south["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(-25,55),
             fontsize=15,
             color="firebrick"
            )
plt.title("Southern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.savefig('../output_data/LatvsTemp_regress_south.png')
plt.show()
# Out:
# The correlation coefficient is: 0.4408514585589044

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_north["Latitude"], weather_df_north["Humidity"])
regress_values = weather_df_north["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(15,10))
plt.scatter(weather_df_north["Latitude"], weather_df_north["Humidity"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_north["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(40,20),
             fontsize=15,
             color="firebrick"
            )
plt.title("Northern Hemisphere - Humidity % vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.savefig('../output_data/LatvsHumidity_regress_north.png')
plt.show()
# Out:
# The correlation coefficient is: 0.39866706749805264

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_south["Latitude"], weather_df_south["Humidity"])
regress_values = weather_df_south["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(15,10))
plt.scatter(weather_df_south["Latitude"], weather_df_south["Humidity"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_south["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(-25,15),
             fontsize=15,
             color="firebrick"
            )
plt.title("Southern Hemisphere - Humidity % vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.savefig('../output_data/LatvsHumidity_regress_south.png')
plt.show()
# Out:
# The correlation coefficient is: 0.2054295461289845

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_north["Latitude"], weather_df_north["Cloudiness"])
regress_values = weather_df_north["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(15,10))
plt.scatter(weather_df_north["Latitude"], weather_df_north["Cloudiness"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_north["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(50,55),
             fontsize=15,
             color="firebrick"
            )
plt.title("Northern Hemisphere - Cloudiness % vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.savefig('../output_data/LatvsCloudiness_regress_north.png')
plt.show()
# Out:
# The correlation coefficient is: 0.29767561502791284

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_south["Latitude"], weather_df_south["Cloudiness"])
regress_values = weather_df_south["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(15,10))
plt.scatter(weather_df_south["Latitude"], weather_df_south["Cloudiness"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_south["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(-55,10),
             fontsize=15,
             color="firebrick"
            )
plt.title("Southern Hemisphere - Cloudiness % vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.savefig('../output_data/LatvsCloudiness_regress_south.png')
plt.show()
# Out:
# The correlation coefficient is: 0.15396379545213082

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_north["Latitude"], weather_df_north["Wind Speed"])
regress_values = weather_df_north["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(15,10))
plt.scatter(weather_df_north["Latitude"], weather_df_north["Wind Speed"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_north["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(10,40),
             fontsize=15,
             color="firebrick"
            )
plt.title("Northern Hemisphere - Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.savefig('../output_data/LatvsWind_regress_north.png')
plt.show()
# Out:
# The correlation coefficient is: 0.05013004624269326

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_south["Latitude"], weather_df_south["Wind Speed"])
regress_values = weather_df_south["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(15,10))
plt.scatter(weather_df_south["Latitude"], weather_df_south["Wind Speed"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_south["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(-55,15),
             fontsize=15,
             color="firebrick"
            )
plt.title("Southern Hemisphere - Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.savefig('../output_data/LatvsWind_regress_south.png')
plt.show()
# Out:
# The correlation coefficient is: -0.3544474074424752

# %% [markdown]
# # APPENDIX

# %% [markdown]
# #### Basic OpenWeather search result (with json)

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "London"
units = "imperial"

# Build query URL
query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + units

response = requests.get(query_url).json()
# json = response.json()

id = response["id"]
print(id)
# lat = response["coord"]["lat"]
# lng = json["coord"]["lon"]
# temperature = json["main"]["temp"]
# humidity = json["main"]["humidity"]
# cloudiness = json["clouds"]["all"]
# windspeed = json["wind"]["speed"]
# pprint(json)
# print(lat)
pprint(response)
# Out:
# 2643743
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 51.51, 'lon': -0.13},
#  'dt': 1580271343,
#  'id': 2643743,
#  'main': {'feels_like': 24.91,
#           'humidity': 80,
#           'pressure': 1005,
#           'temp': 37,
#           'temp_max': 39.2,
#           'temp_min': 35.01},
#  'name': 'London',
#  'sys': {'country': 'GB',
#          'id': 1414,
#          'sunrise': 1580283854,
#          'sunset': 1580316158,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 240, 'speed': 14.99}}

# %% [markdown]
# ***
# <font size="10"><b>WeatherPy<b></font>
# ***

# %% [markdown]
# # SETUP

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

from api_keys import weather_api_key
from api_keys import gkey

from citipy import citipy

# Output file
output_data_file = "output_data/cities.csv"

# Range of latitudes & Longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # GENERATE CITIES LIST

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# # GET DATA

# %% [markdown]
# #### Perform API Calls

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

citynm = []
cityid = []
country = []
lat = []
lng = []
temp = []
hum = []
cloud = []
wind = []
results = []

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Loop each city from the cities list generated above:
for city in cities:
    response = requests.get(query_url + city).json()    
    try:
        citynm_search = response['name']
        cityid_search = response['id']
        citynm.append(response['name'])
        cityid.append(response['id'])
        country.append(response['sys']['country'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response["main"]["temp_max"])
        hum.append(response["main"]["humidity"])
        cloud.append(response["clouds"]["all"])
        wind.append(response["wind"]["speed"])
        results.append(print(f"Search for {citynm_search} (ID: {cityid_search}) found. Results added to library."))
    except (KeyError, IndexError):
        results.append(print(f"***Search for {city} not found. Skipping."))
    time.sleep(1)
        
# Include a print log of each city as it'sbeing processed (with the city number and city name)
# Out:
# Search for Dublin (ID: 5344157) found. Results added to library.
# Search for Nisia Floresta (ID: 3393922) found. Results added to library.
# ***Search for meyungs not found. Skipping.
# Search for Bredasdorp (ID: 1015776) found. Results added to library.
# Search for Paamiut (ID: 3421193) found. Results added to library.
# Search for Kavaratti (ID: 1267390) found. Results added to library.
# Search for Rikitea (ID: 4030556) found. Results added to library.
# Search for Nanortalik (ID: 3421765) found. Results added to library.
# Search for Arandis (ID: 3358670) found. Results added to library.
# Search for Knysna (ID: 988698) found. Results added to library.
# ***Search for karaul not found. Skipping.
# Search for Datong (ID: 2037799) found. Results added to library.
# Search for Albany (ID: 5106841) found. Results added to library.
# Search for Mataura (ID: 6201424) found. Results added to library.
# Search for Atuona (ID: 4020109) found. Results added to library.
# Search for Ushuaia (ID: 3833367) found. Results added to library.
# Search for Severobaykalsk (ID: 2016910) found. Results added to library.
# Search for Leningradskiy (ID: 2123814) found. Results added to library.
# Search for Laas (ID: 3175096) found. Results added to library.
# Search for Asau (ID: 686090) found. Results added to library.
# Search for Olafsvik (ID: 3414079) found. Results added to library.
# Search for George Town (ID: 1735106) found. Results added to library.
# Search for Madang (ID: 2091996) found. Results added to library.
# Search for Vaini (ID: 4032243) found. Results added to library.
# Search for Saint-Paul (ID: 935221) found. Results added to library.
# ***Search for dibaya not found. Skipping.
# Search for Pangnirtung (ID: 6096551) found. Results added to library.
# Search for Sorland (ID: 3137469) found. Results added to library.
# Search for Hermanus (ID: 3366880) found. Results added to library.
# Search for Capaci (ID: 2525392) found. Results added to library.
# Search for East London (ID: 1006984) found. Results added to library.
# Search for Port Alfred (ID: 964432) found. Results added to library.
# Search for Paphos (ID: 146214) found. Results added to library.
# Search for Umea (ID: 602150) found. Results added to library.
# Search for Tuktoyaktuk (ID: 6170031) found. Results added to library.
# Search for Nikolskoye (ID: 546105) found. Results added to library.
# Search for Sitka (ID: 5557293) found. Results added to library.
# Search for Ekpoma (ID: 2343641) found. Results added to library.
# Search for Nome (ID: 5870133) found. Results added to library.
# Search for Faanui (ID: 4034551) found. Results added to library.
# Search for Punta Arenas (ID: 3874787) found. Results added to library.
# Search for Ribeira Grande (ID: 3372707) found. Results added to library.
# ***Search for sumbawa not found. Skipping.
# Search for Lethem (ID: 3379316) found. Results added to library.
# Search for Tiksi (ID: 2015306) found. Results added to library.
# Search for Vanimo (ID: 2084442) found. Results added to library.
# Search for Kodiak (ID: 5866583) found. Results added to library.
# Search for Lebu (ID: 3883457) found. Results added to library.
# Search for San Quintin (ID: 3984997) found. Results added to library.
# Search for Aberdeen (ID: 2657832) found. Results added to library.
# Search for Smithers (ID: 6149996) found. Results added to library.
# Search for Lagoa (ID: 3372964) found. Results added to library.
# Search for Adrar (ID: 2381972) found. Results added to library.
# Search for Shebunino (ID: 2121324) found. Results added to library.
# Search for Kroya (ID: 1639337) found. Results added to library.
# ***Search for yialos not found. Skipping.
# Search for Gizo (ID: 2108857) found. Results added to library.
# Search for Baculin (ID: 1729469) found. Results added to library.
# ***Search for saleaula not found. Skipping.
# Search for Anloga (ID: 2304548) found. Results added to library.
# ***Search for taolanaro not found. Skipping.
# ***Search for tabiauea not found. Skipping.
# Search for Yellowknife (ID: 6185377) found. Results added to library.
# Search for Severo-Kuril'sk (ID: 2121385) found. Results added to library.
# Search for Avarua (ID: 4035715) found. Results added to library.
# Search for Qaanaaq (ID: 3831208) found. Results added to library.
# Search for Cape Town (ID: 3369157) found. Results added to library.
# Search for Ostrovnoy (ID: 556268) found. Results added to library.
# ***Search for barentsburg not found. Skipping.
# Search for Ponta Delgada (ID: 3372783) found. Results added to library.
# Search for Alexandria (ID: 361058) found. Results added to library.
# ***Search for palabuhanratu not found. Skipping.
# Search for Kahului (ID: 5847411) found. Results added to library.
# Search for Carnarvon (ID: 2074865) found. Results added to library.
# Search for Souillac (ID: 933995) found. Results added to library.
# Search for Busselton (ID: 2075265) found. Results added to library.
# Search for Torbay (ID: 6167817) found. Results added to library.
# Search for Geraldton (ID: 2070998) found. Results added to library.
# Search for Kapaa (ID: 5848280) found. Results added to library.
# Search for Iqaluit (ID: 5983720) found. Results added to library.
# Search for Nandgaon (ID: 1261971) found. Results added to library.
# Search for Castro (ID: 3466704) found. Results added to library.
# Search for Waingapu (ID: 1622318) found. Results added to library.
# Search for Casian (ID: 1718170) found. Results added to library.
# Search for Arraial do Cabo (ID: 3471451) found. Results added to library.
# Search for Bluff (ID: 2206939) found. Results added to library.
# Search for Tasiilaq (ID: 3424607) found. Results added to library.
# Search for Kaeo (ID: 2189343) found. Results added to library.
# ***Search for umzimvubu not found. Skipping.
# Search for Ovalle (ID: 3877918) found. Results added to library.
# Search for Klaksvik (ID: 2618795) found. Results added to library.
# Search for Denpasar (ID: 1645528) found. Results added to library.
# Search for Avanuorri (ID: 779622) found. Results added to library.
# Search for Lufilufi (ID: 4035249) found. Results added to library.
# Search for Korla (ID: 1529376) found. Results added to library.
# Search for Cabo San Lucas (ID: 3985710) found. Results added to library.
# Search for Tambura (ID: 366444) found. Results added to library.
# Search for Rock Springs (ID: 5836898) found. Results added to library.
# Search for Rapid Valley (ID: 5768244) found. Results added to library.
# Search for Flinders (ID: 6255012) found. Results added to library.
# Search for Sur (ID: 286245) found. Results added to library.
# Search for Chokurdakh (ID: 2126123) found. Results added to library.
# Search for Hilo (ID: 5855927) found. Results added to library.
# Search for North Bend (ID: 5742974) found. Results added to library.
# Search for Thompson (ID: 6165406) found. Results added to library.
# Search for Wonthaggi (ID: 2154826) found. Results added to library.
# Search for Mar del Plata (ID: 3430863) found. Results added to library.
# ***Search for sentyabrskiy not found. Skipping.
# Search for Clyde River (ID: 5924351) found. Results added to library.
# Search for Lavrentiya (ID: 4031637) found. Results added to library.
# Search for Galveston (ID: 4692856) found. Results added to library.
# Search for Cidreira (ID: 3466165) found. Results added to library.
# Search for San Patricio (ID: 3985168) found. Results added to library.
# Search for Leh (ID: 1264976) found. Results added to library.
# Search for Tarija (ID: 3903320) found. Results added to library.
# Search for Gidam (ID: 1271215) found. Results added to library.
# Search for Necochea (ID: 3430443) found. Results added to library.
# Search for Saldanha (ID: 3361934) found. Results added to library.
# Search for La Ronge (ID: 6050066) found. Results added to library.
# Search for Fairbanks (ID: 5861897) found. Results added to library.
# Search for Twentynine Palms (ID: 5404198) found. Results added to library.
# Search for Ponta do Sol (ID: 2264557) found. Results added to library.
# Search for Karratha (ID: 6620339) found. Results added to library.
# Search for Ilulissat (ID: 3423146) found. Results added to library.
# Search for Marzuq (ID: 72181) found. Results added to library.
# Search for Mahebourg (ID: 934322) found. Results added to library.
# Search for Kenai (ID: 5866063) found. Results added to library.
# Search for Longyearbyen (ID: 2729907) found. Results added to library.
# Search for Richards Bay (ID: 962367) found. Results added to library.
# Search for Zonguldak (ID: 737021) found. Results added to library.
# Search for Vardo (ID: 777019) found. Results added to library.
# Search for Kumul (ID: 1529484) found. Results added to library.
# Search for Hobart (ID: 2163355) found. Results added to library.
# Search for Norman Wells (ID: 6089245) found. Results added to library.
# Search for Port Elizabeth (ID: 964420) found. Results added to library.
# Search for Bulawayo (ID: 894701) found. Results added to library.
# Search for Bathsheba (ID: 3374083) found. Results added to library.
# Search for Mossamedes (ID: 3347019) found. Results added to library.
# ***Search for illoqqortoormiut not found. Skipping.
# ***Search for mys shmidta not found. Skipping.
# Search for Srivardhan (ID: 1255619) found. Results added to library.
# Search for Puerto Ayora (ID: 3652764) found. Results added to library.
# Search for Yarmouth (ID: 4956335) found. Results added to library.
# Search for Tabory (ID: 1490364) found. Results added to library.
# Search for Tigil (ID: 2120612) found. Results added to library.
# Search for Esperance (ID: 2071860) found. Results added to library.
# Search for Padang (ID: 1633419) found. Results added to library.
# Search for Namatanai (ID: 2090021) found. Results added to library.
# Search for Mayor Pablo Lagerenza (ID: 3867427) found. Results added to library.
# Search for Lorengau (ID: 2092164) found. Results added to library.
# Search for Mangan (ID: 1263776) found. Results added to library.
# Search for Butaritari (ID: 2110227) found. Results added to library.
# ***Search for nizhneyansk not found. Skipping.
# Search for Nyrob (ID: 516588) found. Results added to library.
# Search for General Roca (ID: 3855065) found. Results added to library.
# Search for San Rafael (ID: 3836669) found. Results added to library.
# ***Search for attawapiskat not found. Skipping.
# Search for Lompoc (ID: 5367788) found. Results added to library.
# Search for New Norfolk (ID: 2155415) found. Results added to library.
# Search for Ancud (ID: 3899695) found. Results added to library.
# Search for Manaus (ID: 3663517) found. Results added to library.
# Search for Maniitsoq (ID: 3421982) found. Results added to library.
# Search for Pechenga (ID: 511865) found. Results added to library.
# Search for Narsaq (ID: 3421719) found. Results added to library.
# Search for Dikson (ID: 1507390) found. Results added to library.
# Search for Druzhnaya Gorka (ID: 564866) found. Results added to library.
# Search for Dudinka (ID: 1507116) found. Results added to library.
# Search for Jasper (ID: 4392354) found. Results added to library.
# Search for At-Bashi (ID: 1528796) found. Results added to library.
# Search for Port Lincoln (ID: 2063036) found. Results added to library.
# Search for Nouadhibou (ID: 2377457) found. Results added to library.
# Search for Velingara (ID: 2244177) found. Results added to library.
# ***Search for samusu not found. Skipping.
# Search for Barrow (ID: 5880054) found. Results added to library.
# Search for Boa Vista (ID: 3664980) found. Results added to library.
# ***Search for amderma not found. Skipping.
# Search for Salalah (ID: 286621) found. Results added to library.
# Search for Miguel Hidalgo (ID: 3827408) found. Results added to library.
# Search for Yerbogachen (ID: 2012956) found. Results added to library.
# ***Search for khormuj not found. Skipping.
# Search for Vega de Alatorre (ID: 3514843) found. Results added to library.
# Search for Walvis Bay (ID: 3359638) found. Results added to library.
# Search for Nata (ID: 3703938) found. Results added to library.
# Search for Jamestown (ID: 5122534) found. Results added to library.
# Search for Novobirilyussy (ID: 1508260) found. Results added to library.
# Search for Bilma (ID: 2446796) found. Results added to library.
# Search for Saskylakh (ID: 2017155) found. Results added to library.
# Search for Trinidad (ID: 3902377) found. Results added to library.
# Search for Kushima (ID: 1895695) found. Results added to library.
# ***Search for solovetskiy not found. Skipping.
# Search for Kaitangata (ID: 2208248) found. Results added to library.
# Search for Russell (ID: 4047434) found. Results added to library.
# Search for Barcelona (ID: 3128760) found. Results added to library.
# Search for Pacific Grove (ID: 5380437) found. Results added to library.
# Search for Warrington (ID: 2634739) found. Results added to library.
# Search for Van (ID: 298117) found. Results added to library.
# Search for Coahuayana Viejo (ID: 4013679) found. Results added to library.
# Search for Meulaboh (ID: 1214488) found. Results added to library.
# ***Search for belushya guba not found. Skipping.
# Search for Dingle (ID: 1714733) found. Results added to library.
# Search for Bubaque (ID: 2374583) found. Results added to library.
# Search for Annan (ID: 2657293) found. Results added to library.
# Search for Lubango (ID: 3347762) found. Results added to library.
# Search for Bengkulu (ID: 1649150) found. Results added to library.
# Search for Urucui (ID: 3385658) found. Results added to library.
# Search for Ruwi (ID: 287286) found. Results added to library.
# Search for Daru (ID: 2098329) found. Results added to library.
# Search for San Ignacio (ID: 3581194) found. Results added to library.
# Search for Nakamura (ID: 1855891) found. Results added to library.
# Search for Naze (ID: 1855540) found. Results added to library.
# ***Search for karamay not found. Skipping.
# Search for Marawi (ID: 1701054) found. Results added to library.
# Search for Auki (ID: 2109701) found. Results added to library.
# Search for Caravelas (ID: 3466980) found. Results added to library.
# Search for Banda Aceh (ID: 1215502) found. Results added to library.
# ***Search for scottsburgh not found. Skipping.
# Search for Chara (ID: 2025630) found. Results added to library.
# Search for Santa Isabel (ID: 3450188) found. Results added to library.
# Search for Victoriaville (ID: 6174151) found. Results added to library.
# Search for Vizinga (ID: 473263) found. Results added to library.
# Search for Aluksne (ID: 461528) found. Results added to library.
# Search for Belyy Yar (ID: 1510377) found. Results added to library.
# Search for Delvine (ID: 363383) found. Results added to library.
# ***Search for eskasem not found. Skipping.
# Search for Srednekolymsk (ID: 2121025) found. Results added to library.
# Search for Varhaug (ID: 3132644) found. Results added to library.
# Search for Tari (ID: 2322495) found. Results added to library.
# Search for Port Macquarie (ID: 2152659) found. Results added to library.
# ***Search for rungata not found. Skipping.
# ***Search for sorvag not found. Skipping.
# Search for Saint George (ID: 5546220) found. Results added to library.
# Search for Tonekabon (ID: 112656) found. Results added to library.
# Search for Rome (ID: 5134295) found. Results added to library.
# Search for Bilibino (ID: 2126682) found. Results added to library.
# Search for Carutapera (ID: 3402648) found. Results added to library.
# Search for Mwandiga (ID: 153709) found. Results added to library.
# Search for Pokhara (ID: 1282898) found. Results added to library.
# Search for Terrace Bay (ID: 6162951) found. Results added to library.
# Search for Pochutla (ID: 3517970) found. Results added to library.
# Search for Pimentel (ID: 3693584) found. Results added to library.
# Search for Husavik (ID: 2629833) found. Results added to library.
# Search for Upernavik (ID: 3418910) found. Results added to library.
# Search for Healesville (ID: 2163701) found. Results added to library.
# Search for Andijan (ID: 1514588) found. Results added to library.
# Search for Biltine (ID: 244878) found. Results added to library.
# Search for Zhigansk (ID: 2012530) found. Results added to library.
# Search for Tazovsky (ID: 1489853) found. Results added to library.
# ***Search for tumannyy not found. Skipping.
# Search for Luanda (ID: 2240449) found. Results added to library.
# Search for Aklavik (ID: 5882953) found. Results added to library.
# Search for Gravdal (ID: 3155152) found. Results added to library.
# Search for Makakilo City (ID: 5850554) found. Results added to library.
# Search for Kalevala (ID: 554318) found. Results added to library.
# Search for Buwenge (ID: 233886) found. Results added to library.
# Search for Grand Gaube (ID: 934479) found. Results added to library.
# Search for Provideniya (ID: 4031574) found. Results added to library.
# Search for Pagsangahan (ID: 1696524) found. Results added to library.
# ***Search for borlange not found. Skipping.
# Search for Sibolga (ID: 1213855) found. Results added to library.
# Search for Berdigestyakh (ID: 2026861) found. Results added to library.
# Search for Chivilcoy (ID: 3861344) found. Results added to library.
# Search for Lai (ID: 2429296) found. Results added to library.
# Search for Lucea (ID: 3489657) found. Results added to library.
# Search for Edd (ID: 338345) found. Results added to library.
# Search for Vestmannaeyjar (ID: 3412093) found. Results added to library.
# Search for Acapulco de Juarez (ID: 3533462) found. Results added to library.
# Search for Port Hawkesbury (ID: 6111867) found. Results added to library.
# Search for Sao Joao da Barra (ID: 3448903) found. Results added to library.
# Search for Cambridge (ID: 5913695) found. Results added to library.
# Search for Mosquera (ID: 3674292) found. Results added to library.
# Search for Muyezerskiy (ID: 524100) found. Results added to library.
# Search for Rawson (ID: 3839307) found. Results added to library.
# Search for Shimanovsk (ID: 2016701) found. Results added to library.
# Search for Port Moresby (ID: 2088122) found. Results added to library.
# Search for Te Anau (ID: 2181625) found. Results added to library.
# Search for Piploda (ID: 1259571) found. Results added to library.
# Search for Berlevag (ID: 780687) found. Results added to library.
# Search for Airai (ID: 1651810) found. Results added to library.
# Search for Dmitriyevskaya (ID: 566000) found. Results added to library.
# Search for Kurumkan (ID: 2021188) found. Results added to library.
# Search for Key Largo (ID: 4160795) found. Results added to library.
# Search for Salinopolis (ID: 3389822) found. Results added to library.
# Search for Bambous Virieux (ID: 1106677) found. Results added to library.
# Search for Pisco (ID: 3932145) found. Results added to library.
# Search for Haines Junction (ID: 5969025) found. Results added to library.
# Search for Lata (ID: 2738381) found. Results added to library.
# Search for Verkhnetulomskiy (ID: 475469) found. Results added to library.
# Search for Puksoozero (ID: 504187) found. Results added to library.
# Search for Aykhal (ID: 2027296) found. Results added to library.
# Search for Tupik (ID: 2014836) found. Results added to library.
# Search for Luderitz (ID: 3355672) found. Results added to library.
# Search for Belmonte (ID: 3470137) found. Results added to library.
# Search for Sioux Lookout (ID: 6148373) found. Results added to library.
# Search for Camacha (ID: 2270385) found. Results added to library.
# Search for Hong Kong (ID: 1819729) found. Results added to library.
# Search for Ayagoz (ID: 1525988) found. Results added to library.
# ***Search for marcona not found. Skipping.
# Search for Capelinha (ID: 3467305) found. Results added to library.
# Search for Oistins (ID: 3373652) found. Results added to library.
# Search for Ramanathapuram (ID: 1258740) found. Results added to library.
# Search for Xai-Xai (ID: 1024552) found. Results added to library.
# Search for Uncia (ID: 3911409) found. Results added to library.
# Search for Khani (ID: 610864) found. Results added to library.
# Search for Inuvik (ID: 5983607) found. Results added to library.
# Search for Mezen (ID: 527321) found. Results added to library.
# Search for Pogar (ID: 507875) found. Results added to library.
# Search for Hofn (ID: 2630299) found. Results added to library.
# Search for Angoram (ID: 2100765) found. Results added to library.
# Search for Vyritsa (ID: 470368) found. Results added to library.
# Search for Flagstaff (ID: 5294810) found. Results added to library.
# Search for Talnakh (ID: 1490256) found. Results added to library.
# Search for Kongolo (ID: 212360) found. Results added to library.
# Search for Half Moon Bay (ID: 5354943) found. Results added to library.
# Search for Yar-Sale (ID: 1486321) found. Results added to library.
# Search for Perbaungan (ID: 1214191) found. Results added to library.
# Search for Teloloapan (ID: 3516060) found. Results added to library.
# Search for Chui (ID: 3443061) found. Results added to library.
# Search for Galbshtadt (ID: 1497899) found. Results added to library.
# Search for Katsuura (ID: 2112309) found. Results added to library.
# Search for Fortuna (ID: 5563839) found. Results added to library.
# ***Search for tsihombe not found. Skipping.
# Search for Anking (ID: 1817993) found. Results added to library.
# ***Search for buqayq not found. Skipping.
# Search for Sweetwater (ID: 4174600) found. Results added to library.
# Search for Saint-Philippe (ID: 935215) found. Results added to library.
# Search for Beringovskiy (ID: 2126710) found. Results added to library.
# Search for Ossora (ID: 2122389) found. Results added to library.
# Search for Kaspiysk (ID: 551847) found. Results added to library.
# Search for Cherskiy (ID: 2126199) found. Results added to library.
# Search for Krasnofarfornyy (ID: 542400) found. Results added to library.
# Search for Khatanga (ID: 2022572) found. Results added to library.
# Search for Vidim (ID: 2013406) found. Results added to library.
# Search for Prince Rupert (ID: 6113406) found. Results added to library.
# Search for Pilar (ID: 3392126) found. Results added to library.
# Search for Turaif (ID: 101312) found. Results added to library.
# Search for Andenes (ID: 3163146) found. Results added to library.
# Search for Kalmunai (ID: 1242110) found. Results added to library.
# Search for Bulungu (ID: 2316259) found. Results added to library.
# Search for Fes (ID: 2548885) found. Results added to library.
# Search for Puerto Escondido (ID: 3520994) found. Results added to library.
# ***Search for tome-acu not found. Skipping.
# Search for Cerrik (ID: 3185897) found. Results added to library.
# Search for Estelle (ID: 4323873) found. Results added to library.
# Search for Behshahr (ID: 140918) found. Results added to library.
# Search for Westport (ID: 4845585) found. Results added to library.
# Search for Zhalantun (ID: 2033225) found. Results added to library.
# Search for Kattivakkam (ID: 1267433) found. Results added to library.
# Search for Bucerias (ID: 4016734) found. Results added to library.
# Search for Krutikha (ID: 1501706) found. Results added to library.
# Search for Gold Coast (ID: 2165087) found. Results added to library.
# Search for Cap-aux-Meules (ID: 5915327) found. Results added to library.
# ***Search for itapua poty not found. Skipping.
# Search for Wanning (ID: 1791779) found. Results added to library.
# Search for Aykino (ID: 580182) found. Results added to library.
# Search for Grindavik (ID: 3416888) found. Results added to library.
# Search for Mizdah (ID: 2214827) found. Results added to library.
# Search for Cavan (ID: 2965535) found. Results added to library.
# Search for Sampit (ID: 1628884) found. Results added to library.
# Search for Bethel (ID: 5282297) found. Results added to library.
# Search for Bardiyah (ID: 80509) found. Results added to library.
# Search for Gari (ID: 1506676) found. Results added to library.
# Search for Vangaindrano (ID: 1054329) found. Results added to library.
# Search for Vagur (ID: 2610806) found. Results added to library.
# Search for Limon (ID: 3622247) found. Results added to library.
# Search for Roebourne (ID: 2062276) found. Results added to library.
# Search for Eyl (ID: 60019) found. Results added to library.
# Search for Bloomfield (ID: 5095779) found. Results added to library.
# Search for Markova (ID: 701802) found. Results added to library.
# Search for Dongsheng (ID: 1812256) found. Results added to library.
# Search for Fort Nelson (ID: 5955902) found. Results added to library.
# Search for Codrington (ID: 2171099) found. Results added to library.
# Search for Inverell (ID: 2162662) found. Results added to library.
# Search for Miles City (ID: 5666176) found. Results added to library.
# Search for Kruisfontein (ID: 986717) found. Results added to library.
# Search for Ko Samui (ID: 1154689) found. Results added to library.
# Search for Mitsamiouli (ID: 921786) found. Results added to library.
# Search for Aljezur (ID: 2271968) found. Results added to library.
# Search for Tarazona (ID: 3108308) found. Results added to library.
# Search for Yulara (ID: 6355222) found. Results added to library.
# Search for Lakatoro (ID: 2136697) found. Results added to library.
# Search for Puerto Lopez (ID: 3671418) found. Results added to library.
# Search for Ciudad Lazaro Cardenas (ID: 4026082) found. Results added to library.
# Search for Narimanov (ID: 523443) found. Results added to library.
# Search for Cuamba (ID: 1047660) found. Results added to library.
# Search for Ahipara (ID: 2194098) found. Results added to library.
# Search for Guarapari (ID: 3461888) found. Results added to library.
# Search for Crossville (ID: 4616470) found. Results added to library.
# Search for Kodinsk (ID: 1503037) found. Results added to library.
# Search for Barra do Pirai (ID: 3470691) found. Results added to library.
# Search for Humberto de Campos (ID: 3398428) found. Results added to library.
# Search for Plettenberg Bay (ID: 964712) found. Results added to library.
# Search for Lalsk (ID: 537094) found. Results added to library.
# Search for Rio Claro (ID: 3451234) found. Results added to library.
# Search for Moose Factory (ID: 6078372) found. Results added to library.
# ***Search for taburao not found. Skipping.
# ***Search for buariki not found. Skipping.
# Search for Lakes Entrance (ID: 2160735) found. Results added to library.
# Search for Coyhaique (ID: 3894426) found. Results added to library.
# Search for Dombovar (ID: 3053590) found. Results added to library.
# Search for Porto Nacional (ID: 3452711) found. Results added to library.
# Search for Zhuhai (ID: 1790437) found. Results added to library.
# Search for Olesno (ID: 3090158) found. Results added to library.
# Search for Huai Thalaeng (ID: 1610652) found. Results added to library.
# Search for Timmins (ID: 6166739) found. Results added to library.
# Search for Puerres (ID: 3671576) found. Results added to library.
# Search for Storforshei (ID: 3145614) found. Results added to library.
# Search for Wilmington (ID: 4499379) found. Results added to library.
# Search for Portland (ID: 5746545) found. Results added to library.
# Search for Kichera (ID: 2022129) found. Results added to library.
# Search for Beira (ID: 1052373) found. Results added to library.
# Search for Port Shepstone (ID: 964406) found. Results added to library.
# Search for Warmbad (ID: 3352263) found. Results added to library.
# Search for Taoudenni (ID: 2450173) found. Results added to library.
# ***Search for vaitupu not found. Skipping.
# Search for Mount Isa (ID: 2065594) found. Results added to library.
# Search for Chimbote (ID: 3698304) found. Results added to library.
# Search for Agdas (ID: 587378) found. Results added to library.
# Search for Abu Dhabi (ID: 292968) found. Results added to library.
# Search for Viedma (ID: 3832899) found. Results added to library.
# ***Search for satitoa not found. Skipping.
# Search for Chardara (ID: 1524889) found. Results added to library.
# Search for Bayir (ID: 304183) found. Results added to library.
# Search for Deputatsky (ID: 2028164) found. Results added to library.
# Search for Kaitong (ID: 2036338) found. Results added to library.
# Search for Katobu (ID: 1640972) found. Results added to library.
# Search for Ladario (ID: 3459352) found. Results added to library.
# Search for Harbour Breton (ID: 5970478) found. Results added to library.
# Search for Hualmay (ID: 3939761) found. Results added to library.
# Search for Ketchikan (ID: 5554428) found. Results added to library.
# Search for Sanjwal (ID: 1166118) found. Results added to library.
# Search for Guadalupe y Calvo (ID: 4005370) found. Results added to library.
# Search for Kaputa (ID: 176758) found. Results added to library.
# ***Search for louisbourg not found. Skipping.
# Search for Show Low (ID: 5314245) found. Results added to library.
# Search for Rairangpur (ID: 1265830) found. Results added to library.
# Search for Antofagasta (ID: 3899539) found. Results added to library.
# Search for Trenggalek (ID: 1623251) found. Results added to library.
# Search for Yumen (ID: 1528998) found. Results added to library.
# Search for Vondrozo (ID: 1053507) found. Results added to library.
# Search for Sao Gabriel da Cachoeira (ID: 3662342) found. Results added to library.
# Search for Mecca (ID: 104515) found. Results added to library.
# Search for Tilichiki (ID: 2120591) found. Results added to library.
# Search for Chu (ID: 1519030) found. Results added to library.
# Search for Kargat (ID: 1504380) found. Results added to library.
# Search for Saint-Leu (ID: 6690297) found. Results added to library.
# Search for Pemba (ID: 1028918) found. Results added to library.
# Search for Santo Antonio da Platina (ID: 3449529) found. Results added to library.
# Search for Cayenne (ID: 3382160) found. Results added to library.
# Search for Dolores (ID: 3435038) found. Results added to library.
# Search for Riyadh (ID: 108410) found. Results added to library.
# Search for Port Hedland (ID: 2063042) found. Results added to library.
# Search for Oued Meliz (ID: 2464157) found. Results added to library.
# Search for Horki (ID: 627905) found. Results added to library.
# Search for Margate (ID: 2643044) found. Results added to library.
# Search for Bayana (ID: 1276652) found. Results added to library.
# Search for Hay River (ID: 5972762) found. Results added to library.
# Search for Brigantine (ID: 4500920) found. Results added to library.
# Search for Negombo (ID: 1233369) found. Results added to library.
# Search for Burns Lake (ID: 5911745) found. Results added to library.
# Search for Okato (ID: 2185763) found. Results added to library.
# Search for Chapais (ID: 5919850) found. Results added to library.
# Search for Tarko-Sale (ID: 1490085) found. Results added to library.
# Search for Athabasca (ID: 5887916) found. Results added to library.
# ***Search for uroteppa not found. Skipping.
# Search for Vila Franca do Campo (ID: 3372472) found. Results added to library.
# Search for Saint Anthony (ID: 5044290) found. Results added to library.
# ***Search for labutta not found. Skipping.
# Search for Nerekhta (ID: 522594) found. Results added to library.
# Search for Hasaki (ID: 2112802) found. Results added to library.
# Search for La Rioja (ID: 3336897) found. Results added to library.
# ***Search for tunduru not found. Skipping.
# Search for Henties Bay (ID: 3356832) found. Results added to library.
# Search for La Maddalena (ID: 3175217) found. Results added to library.
# Search for Hithadhoo (ID: 1282256) found. Results added to library.
# Search for Sinnamary (ID: 3380290) found. Results added to library.
# Search for Ulladulla (ID: 2145554) found. Results added to library.
# ***Search for grand river south east not found. Skipping.
# Search for Kensington (ID: 2161608) found. Results added to library.
# Search for Nouakchott (ID: 2377450) found. Results added to library.
# Search for Ati (ID: 2436400) found. Results added to library.
# Search for Kununurra (ID: 2068110) found. Results added to library.
# Search for Khuzdar (ID: 7082481) found. Results added to library.
# Search for Nishihara (ID: 1855342) found. Results added to library.
# Search for Rovaniemi (ID: 638936) found. Results added to library.
# Search for Parga (ID: 255736) found. Results added to library.
# Search for Kongsberg (ID: 6453373) found. Results added to library.
# Search for Honningsvag (ID: 779554) found. Results added to library.
# Search for Aksay (ID: 583673) found. Results added to library.
# Search for Gonbad-e Kavus (ID: 132938) found. Results added to library.
# Search for Havre-Saint-Pierre (ID: 5972291) found. Results added to library.
# Search for Frontera (ID: 3980180) found. Results added to library.
# Search for San Juan (ID: 3837213) found. Results added to library.
# Search for Cay (ID: 319104) found. Results added to library.
# Search for Palimbang (ID: 1696105) found. Results added to library.
# Search for Jambi (ID: 1642858) found. Results added to library.
# Search for Honiara (ID: 2108502) found. Results added to library.
# Search for Batemans Bay (ID: 2176639) found. Results added to library.
# Search for Touros (ID: 3386213) found. Results added to library.
# Search for Kidal (ID: 2455290) found. Results added to library.
# Search for Bayanday (ID: 2027004) found. Results added to library.
# Search for Alofi (ID: 4036284) found. Results added to library.
# Search for Entre Rios (ID: 3464100) found. Results added to library.
# Search for Nhulunbuy (ID: 2064735) found. Results added to library.
# Search for Rio Brilhante (ID: 3451241) found. Results added to library.
# Search for Hun (ID: 2216645) found. Results added to library.
# Search for Brae (ID: 2654970) found. Results added to library.
# Search for Iskateley (ID: 866062) found. Results added to library.
# Search for Chiang Klang (ID: 1611195) found. Results added to library.
# Search for Brandon (ID: 4148757) found. Results added to library.
# Search for Tadine (ID: 2138285) found. Results added to library.
# ***Search for kamenskoye not found. Skipping.
# Search for Alihe (ID: 2038665) found. Results added to library.
# Search for Floro (ID: 3156980) found. Results added to library.
# Search for Sharlyk (ID: 495670) found. Results added to library.
# Search for Port Augusta (ID: 2063056) found. Results added to library.
# Search for Koidu (ID: 2407660) found. Results added to library.
# Search for Obo (ID: 236950) found. Results added to library.
# Search for Goderich (ID: 5962442) found. Results added to library.
# Search for Raja (ID: 368246) found. Results added to library.
# Search for Natal (ID: 3394023) found. Results added to library.
# Search for Cervo (ID: 3125287) found. Results added to library.
# Search for Saint-Michel-des-Saints (ID: 6138802) found. Results added to library.
# ***Search for westpunt not found. Skipping.
# Search for Vao (ID: 2137773) found. Results added to library.
# Search for Sept-Iles (ID: 6144312) found. Results added to library.
# Search for Buraidah (ID: 107304) found. Results added to library.
# Search for Kamaishi (ID: 2112444) found. Results added to library.
# Search for Emerald (ID: 2167426) found. Results added to library.
# Search for Aripuana (ID: 3665202) found. Results added to library.
# Search for Rantepao (ID: 1629974) found. Results added to library.
# Search for Port Hardy (ID: 6111862) found. Results added to library.
# Search for Kismayo (ID: 55671) found. Results added to library.
# Search for Mandalgovi (ID: 2030065) found. Results added to library.
# Search for Mayo (ID: 4362001) found. Results added to library.
# Search for Akdepe (ID: 601551) found. Results added to library.
# ***Search for falealupo not found. Skipping.
# Search for Borogontsy (ID: 2026160) found. Results added to library.
# ***Search for chagda not found. Skipping.
# Search for Norden (ID: 2862118) found. Results added to library.
# Search for Pevek (ID: 2122090) found. Results added to library.
# Search for Khash (ID: 1160571) found. Results added to library.
# ***Search for negele not found. Skipping.
# Search for Mehamn (ID: 778707) found. Results added to library.
# Search for Turukhansk (ID: 1488903) found. Results added to library.
# Search for Itarema (ID: 3393692) found. Results added to library.
# Search for Erbaa (ID: 747489) found. Results added to library.
# Search for Hwange (ID: 889942) found. Results added to library.
# Search for Mount Gambier (ID: 2156643) found. Results added to library.
# Search for Waipawa (ID: 2206874) found. Results added to library.
# Search for Virden (ID: 4252060) found. Results added to library.
# Search for Kaka (ID: 161901) found. Results added to library.
# ***Search for malwan not found. Skipping.
# Search for Sokolo (ID: 2450849) found. Results added to library.
# Search for Byron Bay (ID: 2172880) found. Results added to library.
# Search for Darhan (ID: 2031964) found. Results added to library.
# Search for Keti Bandar (ID: 1174451) found. Results added to library.
# Search for Seoul (ID: 1835848) found. Results added to library.
# Search for Vyartsilya (ID: 470762) found. Results added to library.
# Search for Yelnya (ID: 467753) found. Results added to library.
# Search for Kavieng (ID: 2094342) found. Results added to library.
# Search for Morton (ID: 5690583) found. Results added to library.
# Search for Norrtaelje (ID: 2688250) found. Results added to library.
# Search for Olkhovatka (ID: 515539) found. Results added to library.
# Search for Chumikan (ID: 2025256) found. Results added to library.
# Search for Gamba (ID: 2400547) found. Results added to library.
# Search for Moerai (ID: 4034188) found. Results added to library.
# Search for Pangkalanbuun (ID: 1632694) found. Results added to library.
# Search for Ailigandi (ID: 3714956) found. Results added to library.
# ***Search for dzhusaly not found. Skipping.
# Search for Shelburne (ID: 6145890) found. Results added to library.
# Search for Atar (ID: 2381334) found. Results added to library.
# Search for Madimba (ID: 878141) found. Results added to library.
# Search for Wattegama (ID: 1224061) found. Results added to library.
# Search for Northam (ID: 2641434) found. Results added to library.
# Search for Zamania (ID: 1252692) found. Results added to library.
# Search for Altay (ID: 1529651) found. Results added to library.
# Search for Crotone (ID: 2524881) found. Results added to library.
# Search for Jurm (ID: 1139085) found. Results added to library.
# Search for Alice Springs (ID: 2077895) found. Results added to library.
# Search for Sudak (ID: 692315) found. Results added to library.
# Search for Port Keats (ID: 2063039) found. Results added to library.
# Search for Port-Gentil (ID: 2396518) found. Results added to library.
# Search for Chapadinha (ID: 3402229) found. Results added to library.
# Search for Isangel (ID: 2136825) found. Results added to library.
# Search for Serik (ID: 301101) found. Results added to library.
# Search for Nueva Italia (ID: 3437652) found. Results added to library.
# Search for Bambanglipuro (ID: 1650434) found. Results added to library.
# ***Search for nylstroom not found. Skipping.
# Search for Chipinge (ID: 893549) found. Results added to library.
# Search for Porbandar (ID: 1259395) found. Results added to library.
# Search for Hirara (ID: 1862505) found. Results added to library.
# Search for Morondava (ID: 1058381) found. Results added to library.
# Search for Sungaipenuh (ID: 1625929) found. Results added to library.
# Search for Cururupu (ID: 3401148) found. Results added to library.
# Search for Yinchuan (ID: 1786657) found. Results added to library.
# Search for Staryy Nadym (ID: 1490918) found. Results added to library.
# Search for Buta (ID: 217570) found. Results added to library.
# Search for Morro Bay (ID: 5374920) found. Results added to library.
# Search for Muisne (ID: 3653967) found. Results added to library.
# Search for Tsogni (ID: 2400547) found. Results added to library.
# Search for Esik (ID: 1523741) found. Results added to library.
# Search for Kupang (ID: 2057087) found. Results added to library.
# Search for Bentong (ID: 1779790) found. Results added to library.
# Search for Elmira (ID: 5116497) found. Results added to library.
# Search for Dukat (ID: 2125906) found. Results added to library.
# Search for Palamos (ID: 3114566) found. Results added to library.
# Search for Kamenka (ID: 553766) found. Results added to library.
# Search for Porto-Novo (ID: 2392087) found. Results added to library.
# Search for Muzhi (ID: 1498161) found. Results added to library.
# Search for San Cristobal (ID: 3628473) found. Results added to library.
# Search for Lipno (ID: 3093268) found. Results added to library.
# Search for Saint George's (ID: 3579925) found. Results added to library.
# ***Search for rawannawi not found. Skipping.
# Search for Atagay (ID: 1511276) found. Results added to library.
# Search for Chissamba (ID: 3349580) found. Results added to library.
# Search for Thunder Bay (ID: 6166142) found. Results added to library.
# Search for Maceio (ID: 3395981) found. Results added to library.
# Search for Omidiyeh (ID: 121861) found. Results added to library.
# Search for Van Buren (ID: 4134716) found. Results added to library.
# Search for Lianzhou (ID: 1803841) found. Results added to library.
# Search for Uyuni (ID: 3901903) found. Results added to library.
# Search for Bira (ID: 2026659) found. Results added to library.
# Search for Bom Jesus (ID: 3405304) found. Results added to library.
# Search for Kudahuvadhoo (ID: 1337607) found. Results added to library.
# Search for Skibbereen (ID: 2961459) found. Results added to library.
# Search for Flin Flon (ID: 5954718) found. Results added to library.
# Search for Buala (ID: 2109528) found. Results added to library.
# Search for Longyan (ID: 1802276) found. Results added to library.
# ***Search for gurgan not found. Skipping.

# %%
cityid_ct = len(cityid)
lat_ct = len(lat)
lng_ct = len(lng)
temp_ct = len(temp)
hum_ct = len(hum)
cloud_ct = len(cloud)
wind_ct = len(wind)
print(f"Id Count: {cityid_ct}")
print(f"Lat Count: {lat_ct}")
print(f"Lng Count: {lng_ct}")
print(f"Temp Count: {temp_ct}")
print(f"Hum Count: {hum_ct}")
print(f"Cloud Count: {cloud_ct}")
print(f"Wind Count: {wind_ct}")
# Out:
# Id Count: 577
# Lat Count: 577
# Lng Count: 577
# Temp Count: 577
# Hum Count: 577
# Cloud Count: 577
# Wind Count: 577

# %% [markdown]
# #### Convert Raw Data to DataFrame

# %%
# Display the DataFrame
weather_dict = {
    "City": citynm,
    "CityID": cityid,
    "Country": country,
    "Latitude": lat,
    "Longitude": lng,
    "Temperature": temp,
    "Humidity": hum,
    "Cloudiness": cloud,
    "Wind Speed": wind
}
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#              City   CityID Country  Latitude  Longitude  Temperature  \
# 0          Dublin  5344157      US     37.70    -121.94        55.40
# 1  Nisia Floresta  3393922      BR     -6.09     -35.21        87.80
# 2      Bredasdorp  1015776      ZA    -34.53      20.04        69.80
# 3         Paamiut  3421193      GL     61.99     -49.67        25.30
# 4       Kavaratti  1267390      IN     10.57      72.64        82.92
#
#    Humidity  Cloudiness  Wind Speed
# 0        87          75        5.82
# 1        70          75       16.11
# 2        64          25       16.11
# 3        69         100       35.72
# 4        68           0        3.11

# %%
weather_df.dtypes
# Out:
# City            object
# CityID           int64
# Country         object
# Latitude       float64
# Longitude      float64
# Temperature    float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# dtype: object

# %%
weather_df.isnull().sum()
# Out:
# City           0
# CityID         0
# Country        0
# Latitude       0
# Longitude      0
# Temperature    0
# Humidity       0
# Cloudiness     0
# Wind Speed     0
# dtype: int64

# %%
# Export the city data into a .csv
weather_df.to_csv(output_data_file, mode = "w", index=False)

# %% [markdown]
# # SCATTER PLOTS

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(15,10))
plt.scatter(weather_df["Latitude"], weather_df["Temperature"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.title("City Latitude vs Temperature")
plt.xlabel("City Latitude")
plt.ylabel("Temperature (F)")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Humidity"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.title("City Latitude vs Humidity")
plt.xlabel("City Latitude")
plt.ylabel("Humidity")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.title("City Latitude vs Cloudiness %")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness %")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.title("City Latitude vs Wind Speed")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)
plt.show()

# %% [markdown]
# # LINEAR REGRESSION

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
weather_df_north = weather_df[weather_df.Latitude >= 0]
weather_df_north.head()
# Out:
#          City   CityID Country  Latitude  Longitude  Temperature  Humidity  \
# 0      Dublin  5344157      US     37.70    -121.94        55.40        87
# 3     Paamiut  3421193      GL     61.99     -49.67        25.30        69
# 4   Kavaratti  1267390      IN     10.57      72.64        82.92        68
# 6  Nanortalik  3421765      GL     60.14     -45.24        24.12        80
# 9      Datong  2037799      CN     40.09     113.29        13.41        78
#
#    Cloudiness  Wind Speed
# 0          75        5.82
# 3         100       35.72
# 4           0        3.11
# 6         100        9.91
# 9          27        1.77

# %%
weather_df_north.shape
# Out:
# (390, 9)

# %%
weather_df_south = weather_df[weather_df.Latitude <= 0]
weather_df_south.head()
# Out:
#              City   CityID Country  Latitude  Longitude  Temperature  \
# 1  Nisia Floresta  3393922      BR     -6.09     -35.21        87.80
# 2      Bredasdorp  1015776      ZA    -34.53      20.04        69.80
# 5         Rikitea  4030556      PF    -23.12    -134.97        78.94
# 7         Arandis  3358670      NA    -22.42      14.97        71.01
# 8          Knysna   988698      ZA    -34.04      23.05        64.40
#
#    Humidity  Cloudiness  Wind Speed
# 1        70          75       16.11
# 2        64          25       16.11
# 5        78           0       18.77
# 7        84           0        3.00
# 8        85          75       17.22

# %%
weather_df_south.shape
# Out:
# (187, 9)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_north["Latitude"], weather_df_north["Temperature"])
regress_values = weather_df_north["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(15,10))
plt.scatter(weather_df_north["Latitude"], weather_df_north["Temperature"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_north["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(0,-20),
             fontsize=15,
             color="firebrick"
            )
plt.title("Northern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.show()
# Out:
# The correlation coefficient is: -0.85347895382181

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_south["Latitude"], weather_df_south["Temperature"])
regress_values = weather_df_south["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(weather_df_south["Latitude"], weather_df_south["Temperature"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_south["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(-25,55),
             fontsize=15,
             color="firebrick"
            )
plt.title("Southern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.show()
# Out:
# The correlation coefficient is: 0.4313152392977721

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_north["Latitude"], weather_df_north["Humidity"])
regress_values = weather_df_north["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(weather_df_north["Latitude"], weather_df_north["Humidity"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_north["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(40,20),
             fontsize=15,
             color="firebrick"
            )
plt.title("Northern Hemisphere - Humidity % vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.show()
# Out:
# The correlation coefficient is: 0.40999498735516676

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_south["Latitude"], weather_df_south["Humidity"])
regress_values = weather_df_south["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(weather_df_south["Latitude"], weather_df_south["Humidity"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_south["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(-25,15),
             fontsize=15,
             color="firebrick"
            )
plt.title("Southern Hemisphere - Humidity % vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.show()
# Out:
# The correlation coefficient is: 0.2906983995424471

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_north["Latitude"], weather_df_north["Cloudiness"])
regress_values = weather_df_north["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(weather_df_north["Latitude"], weather_df_north["Cloudiness"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_north["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(50,55),
             fontsize=15,
             color="firebrick"
            )
plt.title("Northern Hemisphere - Cloudiness % vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.show()
# Out:
# The correlation coefficient is: 0.29347389392597795

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_south["Latitude"], weather_df_south["Cloudiness"])
regress_values = weather_df_south["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(weather_df_south["Latitude"], weather_df_south["Cloudiness"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_south["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(-55,10),
             fontsize=15,
             color="firebrick"
            )
plt.title("Southern Hemisphere - Cloudiness % vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.show()
# Out:
# The correlation coefficient is: 0.3385594100995034

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_north["Latitude"], weather_df_north["Wind Speed"])
regress_values = weather_df_north["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(weather_df_north["Latitude"], weather_df_north["Wind Speed"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_north["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(10,40),
             fontsize=15,
             color="firebrick"
            )
plt.title("Northern Hemisphere - Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.show()
# Out:
# The correlation coefficient is: 0.2419407960988925

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_df_south["Latitude"], weather_df_south["Wind Speed"])
regress_values = weather_df_south["Latitude"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(weather_df_south["Latitude"], weather_df_south["Wind Speed"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(weather_df_south["Latitude"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(-30,25),
             fontsize=15,
             color="firebrick"
            )
plt.title("Southern Hemisphere - Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.show()
# Out:
# The correlation coefficient is: -0.28413877299335016

# %% [markdown]
# # APPENDIX

# %% [markdown]
# #### Basic OpenWeather search result (with json)

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "London"
units = "imperial"

# Build query URL
query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + units

response = requests.get(query_url).json()
# json = response.json()

id = response["id"]
print(id)
# lat = response["coord"]["lat"]
# lng = json["coord"]["lon"]
# temperature = json["main"]["temp"]
# humidity = json["main"]["humidity"]
# cloudiness = json["clouds"]["all"]
# windspeed = json["wind"]["speed"]
# pprint(json)
# print(lat)
pprint(response)
# Out:
# 2643743
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 51.51, 'lon': -0.13},
#  'dt': 1579792327,
#  'id': 2643743,
#  'main': {'feels_like': 42.46,
#           'humidity': 87,
#           'pressure': 1030,
#           'temp': 45.03,
#           'temp_max': 46.4,
#           'temp_min': 43},
#  'name': 'London',
#  'sys': {'country': 'GB',
#          'id': 1414,
#          'sunrise': 1579765917,
#          'sunset': 1579797126,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 7000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'speed': 1.12}}
